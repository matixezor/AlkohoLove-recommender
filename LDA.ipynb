# %%
import os
import pandas as pd
import spacy

from dotenv import load_dotenv
from scipy.sparse import coo_matrix
from IPython.display import display
from gensim import corpora, models, similarities

load_dotenv()

DB_URL = os.getenv('DB_URL')

pd.set_option('display.max_columns', 50)

# %%
from pymongo import MongoClient, InsertOne

client = MongoClient(DB_URL)
db = client['alkoholove']

# %%
ALCOHOL_COLUMNS = ['_id', 'name', 'kind', 'type', 'description', 'taste', 'aroma', 'finish', 'country']
# name, kind, type, description, taste, aroma, finish, country
alcohols_collection = db['alcohols']
num_topics = len(alcohols_collection.distinct("type"))

items = list(alcohols_collection.find({}, {field_name: 1 for field_name in ALCOHOL_COLUMNS}))
display(items)
items_data = [
    f'{item["name"]}, {item["kind"]}, {item["type"]}, {item["description"]} {", ".join(item["taste"])} {", ".join(item["aroma"])} {", ".join(item["finish"])}, {item["country"]}'
    for item in items
]
# Out:
# [{'_id': ObjectId('62aa2b37e33ccae4961a4daa'),
#   'name': 'Jägermeister',
#   'kind': 'likier',
#   'type': 'Ziołowy',
#   'description': 'Skład likieru Jägermeister od niemal stu lat utrzymywana jest w tajemnicy. Jak wiadomo z etykiety, likier zawiera aż 56 ziół i przypraw, które od lat niezmiennie budują smak i aromat trunku.',
#   'country': 'Niemcy',
#   'finish': [],
#   'aroma': ['imbir', 'goździki'],
#   'taste': ['imbir', 'skórki cytrusów', 'ziołowy']},
#  {'_id': ObjectId('62ab28e88a757f60cc3f31db'),
#   'name': ' Biały Bocian Słony Karmel',
#   'kind': 'likier',
#   'type': 'mleczny',
#   'description': 'Mleczny likier o modnym smaku słonego karmelu. Bardzo eleganckie połączenie karmelu, mlecznej, białej czekolady, nugatu, ale wyczuwalna jest już w zapachu słoność. Przyjemny smak, delikatny, nie za słodki – biała czekolada, orzechy, finisz to harmonijne połączenie sporej porcji słodyczy ze słonością.',
#   'country': 'Polska',
#   'finish': ['słodki', 'słony'],
#   'aroma': ['słony karmel', 'biała czekolada', 'nugat', 'morska sól'],
#   'taste': ['biała czekolada', 'wanillia', 'delikatny']},
#  {'_id': ObjectId('62ab2a32fd2e7fbd58da41d9'),
#   'name': 'Biały Bocian Advocat',
#   'kind': 'likier',
#   'type': 'jajeczny',
#   'description': 'Aksamitny i delikatny likier jajeczny z dodatkiem mleka. Wyjątkowy smak zawdzięcza połączeniu naturalnych składników: sprowadzanej z Madagaskaru wanilii, aromatycznej brandy, doskonałego spirytusu z wielkopolskich zbóż oraz świeżych żółtek jaj kurzych',
#   'country': 'Polska',
#   'finish': ['łagodny', 'mleczny'],
#   'aroma': ['advokat', 'wanilia'],
#   'taste': ['wanilia', 'jaja kurze']},
#  {'_id': ObjectId('62ab611c4a2fcedd4ce86a79'),
#   'name': 'James cook white oversea',
#   'kind': 'rum',
#   'type': 'biały',
#   'description': 'Łagodny smak, najczęściej wykorzystywany jest do przygotowywania drinków, w których pożądany jest łagodny smak (np. Pina Colada, Mojito, Cuba Libre)',
#   'country': 'Niemcy',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62ab638288a7811f65839221'),
#   'name': ' Krupnik Słony Karmel',
#   'kind': 'likier',
#   'type': 'mleczny',
#   'description': 'Wyprodukowany ze 100% naturalnych składników. Najlepiej pije się go samego lub można połączyć go z ulubionym whisky. Likier ma fantastyczną aksamitną konsystencję i piękny bursztynowy kolor.',
#   'country': 'Polska',
#   'finish': ['łagodny', 'słodki', 'słony'],
#   'aroma': ['karmel', 'sól'],
#   'taste': ['śmietanka', 'karmel', 'sól']},
#  {'_id': ObjectId('62ab661388a7811f65839222'),
#   'name': 'Havana Club Anejo Especial',
#   'kind': 'rum',
#   'type': 'złoty',
#   'description': 'Mieszanka starszych i młodszych rumów. Została poddana procesowi starzeniu do 5 lat. Łączy on w sobie lekkość białego rumu i aromat rumu ciemnego. Charakteryzuje się jasnym, ciepłym, przykuwającym uwagę, złotym kolorem. Najlepiej smakuje z colą, limonką i lodem.',
#   'country': 'Kuba',
#   'finish': ['długi', 'korzenny', 'waniliowy'],
#   'aroma': ['trzcina cukrowa', 'wanilia', 'miód', 'cynamon', 'kawa', 'tytoń'],
#   'taste': ['cynamon', 'kawa', 'wanilia', 'kakao', 'cukier trzcinowy']},
#  {'_id': ObjectId('62ab681f88a7811f65839223'),
#   'name': 'Sheridans Coffee Layered Liqueur',
#   'kind': 'likier',
#   'type': 'kawowy',
#   'description': 'Unikatowa butelka podzielona na dwie części. W jednej zawarty jest napój kawowy a w drugiej napój z mlecznej czekolady. Likier zawiera doskonałej jakości irlandzką whisky.',
#   'country': 'Irlandia',
#   'finish': ['kawowy'],
#   'aroma': ['kawowy', 'mleczny'],
#   'taste': ['słodki', 'kawowy', 'mleczny', 'biała czekolada']},
#  {'_id': ObjectId('62ab6afe4a2fcedd4ce86a7a'),
#   'name': 'Captain Morgan Original Spiced Gold',
#   'kind': 'rum',
#   'type': 'złoty',
#   'description': 'Świetnie komponuje się z colą, sokiem jabłkowym lub napojem imbirowym. Mix rumów prosto z Karaibów. Drobiazgowo kontrolowany proces potrójnej destylacji oraz leżakowanie w dębowych beczkach po Bourbonie. Wyróżnia się unikalną głębią i intensywnością smaku.',
#   'country': 'Anglia',
#   'finish': ['łagodny'],
#   'aroma': ['wanilia', 'przyprawy', 'owoce'],
#   'taste': ['wanilia', 'cynamon', 'kwiaty']},
#  {'_id': ObjectId('62ab6cb588a7811f65839224'),
#   'name': 'Captain Morgan White Rum',
#   'kind': 'rum',
#   'type': 'biały',
#   'description': 'Idealnie pasuje pod bazę do drinków. Jest to lekki i rześki rum o zrównoważonym i kremowym charakterem. Posiada lżejszy bukiet smakowy i ze względu na to, że jest to biały rum to nie jest taki głęboki w porównaniu do innych rumów.',
#   'country': 'Anglia',
#   'finish': ['wytrawny'],
#   'aroma': ['palony cukier', 'orzech'],
#   'taste': ['lekki', 'słodki', 'rześki']},
#  {'_id': ObjectId('62ab6eca88a7811f65839225'),
#   'name': 'She Słony Karmel',
#   'kind': 'likier',
#   'type': 'mleczny',
#   'description': 'To połączenie najwyższej jakości składników z wyjątkowymi recepturami. Kolekcja SHE jest idealną propozycją dla kobiet poszukujących nowych doznań smakowych, czerpiących radość ze wspólnych chwil spędzonych w damskim gronie. Uwagę przykuwa smukła butelka w eleganckiej, matowej czerni z wyrazistymi elementami kolorystycznymi. Świetnie smakuję sam ale również w połączeniu z rumem.',
#   'country': 'Polska',
#   'finish': ['słodki', 'słony'],
#   'aroma': ['karmel', 'mleczny', 'słony'],
#   'taste': ['słodki', 'słony']},
#  {'_id': ObjectId('62ab70624a2fcedd4ce86a7b'),
#   'name': 'She Kawa Z Pomarańczą',
#   'kind': 'likier',
#   'type': 'kawowy',
#   'description': 'To połączenie najwyższej jakości składników z wyjątkowymi recepturami. Kolekcja SHE jest idealną propozycją dla kobiet poszukujących nowych doznań smakowych, czerpiących radość ze wspólnych chwil spędzonych w damskim gronie. Uwagę przykuwa smukła butelka w eleganckiej, matowej czerni z wyrazistymi elementami kolorystycznymi. Świetnie smakuje połączony z piwem, espresso lub mlekiem.',
#   'country': 'Polska',
#   'finish': ['łagodny', 'kawowy'],
#   'aroma': ['pomarańcza', 'kawa'],
#   'taste': ['kawa', 'pomarańcza', 'słodki', 'łagodny']},
#  {'_id': ObjectId('62ab732b88a7811f65839226'),
#   'name': 'Gran Imperio Rhum Superior 7 YO',
#   'kind': 'rum',
#   'type': 'złoty',
#   'description': 'Poddany procesie starzenia. Dobrze komponuje się jako składnik drinków. Posiada lekkie akcenty owocowe zawarte w smaku jak i aromacie. Jest to charakterystyczne dla starzonych rumów.',
#   'country': 'Włochy',
#   'finish': ['krótki', 'alkoholowy', 'pieprzny'],
#   'aroma': ['ananas', 'cynamon', 'goździki', 'pomarańcze', 'alkoholowy'],
#   'taste': ['alkoholowy',
#    'mango',
#    'ananas',
#    'przyprawy korzenne',
#    'goryczkowy']},
#  {'_id': ObjectId('62ab74e788a7811f65839227'),
#   'name': 'Captain Morgan Black Spiced',
#   'kind': 'rum',
#   'type': 'czarny',
#   'description': 'Bardzo aromatyczny alkohol stworzony z karaibskiego rumu. Idealnie smakuje w schłodzonych shotach. Ten podwójnie ciemny rum został starzony w podwójnie opalanych beczkach oraz został wymieszany ze starannie wyselekcjonowanymi przyprawami.',
#   'country': 'Anglia',
#   'finish': [],
#   'aroma': ['przyprawy', 'masło', 'czekolada'],
#   'taste': ['orzechy', 'wanilia', 'goździki', 'czekolada mleczna']},
#  {'_id': ObjectId('62ab772888a7811f65839228'),
#   'name': 'Havana Club Anejo 3 Anos',
#   'kind': 'rum',
#   'type': 'biały',
#   'description': 'Jest to klarowny, jasny rum o delikatnym zabarwieniu. Trzyletni Havana Club to biały rum, który po okresie dojrzewania jest filtrowany w celu usunięcia koloru i utrzymania przeźroczystości. Na szczęście, nie traci przy tym swojego delikatnego charakteru i słodkich nut owocowych, tytoniowych i waniliowych. Idealny do Mojito i Daiquiri. ',
#   'country': 'Anglia',
#   'finish': ['średnio długi', 'lekka goryczka'],
#   'aroma': ['pieprz', 'lukrecja', 'gruszka', 'cytrusy', 'toffi'],
#   'taste': ['banan', 'gruszka', 'cynamon', 'pieprz']},
#  {'_id': ObjectId('62ab798f88a7811f65839229'),
#   'name': 'Captain Morgan Dark Rum',
#   'kind': 'rum',
#   'type': 'czarny',
#   'description': 'Blendowany rum w stylu angielskim. Gładki, bogaty i dębowy smak rumu Captain Morgan Dark sprawia, że \u200b\u200bjest to idealny trunek do picia w stanie czystym lub zacumowanym na skałach. Aby uzyskać prawdziwy poncz rumowy, możesz zmieszać z jednym z ulubionych koktajli z ciemnym rumem Kapitana.',
#   'country': 'Anglia',
#   'finish': ['słodki', 'dymny', 'karmel', 'czekolada'],
#   'aroma': ['karmel', 'czekolada', 'przyprawowy'],
#   'taste': ['karmel', 'melasa', 'czekolada']},
#  {'_id': ObjectId('62ab7bed88a7811f6583922a'),
#   'name': 'Bacardi Carta Negra',
#   'kind': 'rum',
#   'type': 'czarny',
#   'description': 'Świetny składnik drinków, ale również dobrze smakuje w shotach. Doskonale smakuje z pomarańczą i cynamonem. Charakteryzuje się słodkim początkiem tropikalnych owoców połączony z delikatnymi nutami maślanymi nutami karmelu i wanilii kończąc na wędzonej lukrecji i melasą. ',
#   'country': 'Puerto Rico',
#   'finish': ['krótki', 'słodki'],
#   'aroma': ['egzotyczne owoce', 'palone migdały', 'wanilia', 'karmel'],
#   'taste': ['wanilia', 'owoce', 'czekolada']},
#  {'_id': ObjectId('62ab7d6b88a7811f6583922b'),
#   'name': 'Bacardi Spiced',
#   'kind': 'rum',
#   'type': 'złoty',
#   'description': 'Wpisuje się w modny trend rumów aromatyzowanych, zwanych spiced. Destylat dojrzewa w beczkach po amerykańskim bourbonie przez okres od 1 do 2 lat.',
#   'country': 'Puerto Rico',
#   'finish': ['słodki', 'średnio długi', 'przyprawy korzenne'],
#   'aroma': ['wanilia', 'słodkie przyprawy', 'karmel', 'suszone owoce'],
#   'taste': ['słodko-pikantny', 'lekko dymny', 'cynamon', 'owoce', 'karmel']},
#  {'_id': ObjectId('62ab7e8e88a7811f6583922c'),
#   'name': 'Kraken Black Spiced',
#   'kind': 'rum',
#   'type': 'czarny',
#   'description': 'Oryginalny rum z Wysp Karaibskich destylowany w tradycyjnych alembikach. Następnie dojrzewa w dębowych beczkach przez okres 12-24 miesięcy. Specjalna kompozycja ziół dodawana w procesie produkcji tworzy niepowtarzalny smak, który zachwyca swoją gładkością i złożonym charakterem, w którym dominują akcenty mocnego espresso, karmelu, imbiru oraz goździków. ',
#   'country': '',
#   'finish': ['długi', 'wanilia', 'imbir'],
#   'aroma': ['wanilia', 'cynamon', 'czekolada', 'cukier', 'kawa'],
#   'taste': ['wanilia', 'czekolada', 'cynamon']},
#  {'_id': ObjectId('62ab8a511595535727acda31'),
#   'name': 'Malibu Original',
#   'kind': 'likier',
#   'type': 'biały',
#   'description': 'Malibu swietnie nadaje się do różnych drinków. Świeży, łagodny smak zamknięty w butelce. Najlepiej sprzedający się na świecie rum karaibski o smaku kokosowym. Dobrze łączy się z mlekiem. Początkowo miał służyć barmanom do tworzenia Pina Colada.',
#   'country': 'hiszpania',
#   'finish': ['słodki', 'łagodny'],
#   'aroma': ['kokosowy', 'cukier trzcinowy', 'korzenie'],
#   'taste': ['słodki', 'orzeźwiający', 'kokos', 'owoce egzotyczne']},
#  {'_id': ObjectId('62ab8c2e1595535727acda32'),
#   'name': 'Crema Typ Latte Macchiato',
#   'kind': 'likier',
#   'type': 'mleczny',
#   'description': 'Idealny dodatek do kawy, lodów i innych deserów. Pasuje również z mlekiem i lodem',
#   'country': 'Słowacja',
#   'finish': ['krótki', 'kawowy'],
#   'aroma': ['kawowy'],
#   'taste': ['kawowy', 'mleczny', 'słodki', 'śmietankowy']},
#  {'_id': ObjectId('62ac5091dd8b1786279d61c2'),
#   'name': 'Silvaner Trocken',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Eleganckie wytrawne wino pochodzące z Niemiec. Idealne do czerwonych mięs.',
#   'country': 'Niemcy',
#   'finish': [],
#   'aroma': ['jabłko', 'mirabelka', 'cytrusy'],
#   'taste': []},
#  {'_id': ObjectId('62ac5502dd8b1786279d61c3'),
#   'name': 'Cabernet Sauvignon',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Czerwone niezbyt mocne wino. Wyczuwalne nuty truskawek i dębu.',
#   'country': 'Włochy',
#   'finish': [],
#   'aroma': ['truskawka', 'wanilia', 'dąb'],
#   'taste': []},
#  {'_id': ObjectId('62ac632cdd8b1786279d61c4'),
#   'name': 'Chardonnay Viognie, Reserva Privada',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Orzeźwiające wytrawne wino pochodzące z Chile.',
#   'country': 'Chile',
#   'finish': [],
#   'aroma': ['brzoskwinia', 'melon', 'cytrusy'],
#   'taste': []},
#  {'_id': ObjectId('62ac6568dd8b1786279d61c5'),
#   'name': 'Chevalier de Fauvert, Comté Tolosan',
#   'kind': 'wino',
#   'type': 'półsłodkie',
#   'description': 'Białe owocowe wino wyprodukowane we Francji. Orzeźwiające z delikatną słodyczą sprawia, że idealnie pasuje do deserów',
#   'country': 'Francja',
#   'finish': [],
#   'aroma': ['brzoskwinia', 'mandarynka', 'mirabelka'],
#   'taste': []},
#  {'_id': ObjectId('62ac6a83dd8b1786279d61c6'),
#   'name': 'NEGROAMARO SALENTO',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Wino o rubinowej barwie. Wytrawny i cierpki trunek o aromacie suszonych owoców i kakao.',
#   'country': 'Włochy',
#   'finish': [],
#   'aroma': ['suszone owoce', 'czarna porzeczka', 'wołowina'],
#   'taste': []},
#  {'_id': ObjectId('62ac6c9f32e5ed3756d50aa8'),
#   'name': 'Carlo Rossi Refresh, Tropical Moscato',
#   'kind': 'wino',
#   'type': 'słodkie',
#   'description': 'Słodkie wino pełne słodyczy i orzeźwiających nut.',
#   'country': 'USA',
#   'finish': [],
#   'aroma': ['mango', 'ananas', 'marakuja'],
#   'taste': []},
#  {'_id': ObjectId('62ad91cc4df8e18dee66ece9'),
#   'name': 'Carlo Rossi, Pink Moscato',
#   'kind': 'wino',
#   'type': 'słodkie',
#   'description': 'Słodkie, lekkie i orzeźwiające wino z nutami kwiatów i soczystych owoców.',
#   'country': 'USA',
#   'finish': [],
#   'aroma': ['mandarynka', 'brzoskwinia', 'kwiaty'],
#   'taste': []},
#  {'_id': ObjectId('62ad933f4df8e18dee66ecea'),
#   'name': 'Carlo Rossi Sweet Red',
#   'kind': 'wino',
#   'type': 'słodkie',
#   'description': 'Słodkie czerwone wino o aromacie świeżych owoców i wanilii. Cechuje się bogatym i zbalansowanym smakiem.',
#   'country': 'USA',
#   'finish': [],
#   'aroma': ['wanilia'],
#   'taste': []},
#  {'_id': ObjectId('62ad948d6c6632251e9aae41'),
#   'name': 'Merlot, Cimarosa',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': '',
#   'country': 'Chile',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62ad97654df8e18dee66eceb'),
#   'name': 'Chenin Blanc',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': '',
#   'country': 'Południowa Afryka',
#   'finish': [],
#   'aroma': ['melon', 'jabłko', 'cytrusy'],
#   'taste': []},
#  {'_id': ObjectId('62ae1859fd38b436cf924196'),
#   'name': 'Canari Salted Caramel',
#   'kind': 'likier',
#   'type': 'mleczny',
#   'description': 'Doskonały kremowy likier o wyśmienitym smaku karmelu wzbogaconego solą, który świetnie pasuje zarówno do deserów jak i sprawdzi się pity solo.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['karmel'],
#   'taste': ['słony', 'karmel', 'mleczny', 'delikatny']},
#  {'_id': ObjectId('62ae1b68fd38b436cf924197'),
#   'name': 'Soplica Śliwkowa',
#   'kind': 'likier',
#   'type': 'owocowy',
#   'description': 'Starannie wyselekcjonowane owoce oraz profesjonalne przetwórstwo sprawiają, że jest wysokiej jakości trunek. Świetnie smakuje jako shot jak i nadaje się na drinki owocowe na przykład z sokiem z pomarańczy lub żurawiny',
#   'country': 'Polska',
#   'finish': ['łagodny'],
#   'aroma': ['śliwkowy'],
#   'taste': ['śliwkowy']},
#  {'_id': ObjectId('62ae1dcbfd38b436cf924198'),
#   'name': 'Lubuski Gin',
#   'kind': 'gin',
#   'type': 'destylowany',
#   'description': 'Gin Lubuski wytwarzany jest według niezmiennej receptury od 1987 roku. Wyróżnia się wyrazistym smakiem jałowca. Świetnie nadaje się do drinków na przykład z tonikiem. Typ tego ginu świadczy o wysokiej jakości.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['jałowca', 'majeranku', 'lawendy', 'kolendry'],
#   'taste': ['jałowca']},
#  {'_id': ObjectId('62ae1faefd38b436cf924199'),
#   'name': 'Soplica Orzech Laskowy',
#   'kind': 'likier',
#   'type': 'orzechowy',
#   'description': 'Aromatyczna nuta orzechów laskowych zapewniają łagodny i kremowy smak. Można pić jako shot, ale również świetnie komponuje się z dodatkiem gorącej czekolady.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['orzech laskowy', 'wanilia', 'toffi'],
#   'taste': ['orzech laskowy', 'słodki', 'rozgrzewający']},
#  {'_id': ObjectId('62ae20f9fd38b436cf92419a'),
#   'name': 'Soplica Kawowa',
#   'kind': 'likier',
#   'type': 'kawowy',
#   'description': 'Głęboki smak wyjątkowo aromatycznej kawy połączony z przyjemną nutą słodyczy. Świetnie nadaje się solo, ale również pasuje z tonikiem, czekoladą lub kawą.',
#   'country': 'Polska',
#   'finish': ['łagodny'],
#   'aroma': ['kawowy'],
#   'taste': ['kawowy', 'słodki']},
#  {'_id': ObjectId('62b355ec568ac44060a46d67'),
#   'name': 'Dalkowski ananasowy',
#   'kind': 'likier',
#   'type': 'ananasowy',
#   'description': 'Na bazie ',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['ananasowy'],
#   'taste': ['ananasowy']},
#  {'_id': ObjectId('62b3564b568ac44060a46d68'),
#   'name': 'Adam Mickiewicz',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Wodka Adam Mickiewicz jest symbolem tradycji. W hołdzie wielkiemu Polakowi dedykujemy tak wyjątkowy produkt. Dlatego wódka Adam Mickiewicz nie może zawieźć degustatorów pod żadnym względem. Aby tak się stało, nad całym procesem czuwa wiele osób. Producent BZK ALKO tworzy ją na podstawie receptury inspirowanej XIX wiekiem. Adam Mickiewicz wódka zostaje poddawana wielostopniowej filtracji węglem, przy czym jest wielokrotnie destylowana. Wódka powstała z alkoholu etylowego najwyższej jakości pochodzenia kukurydzianego, czyli zboża pozbawionego glutenu. Dzięki odpowiedniej selekcji surowców bez GMO z certyfikowanych gospodarstw. Drugim rodzajem tego alkoholu jest Adam Mickiewicz leżakowana. Wódka Premium to wyjątkowe połączenie aksamitnie gładkiego smaku. Zamkniętego w smukłej, miedziano-czarnej butelce. Swoją niezwykłość zawdzięcza minimum 7-tygodniowemu leżakowaniu w metalowych zbiornikach. Okresowym mieszaniu, które umożliwiają kontakt z powietrzem i harmonizację płynu. Używany do produkcji wódki najwyższej jakości spirytus jest siedmiokrotnie destylowany. Produkt doskonale nadaje się jako prezent. Jak i na wspólne spotkania okraszone dobrym alkoholem. Zawartość alkoholu: 40%',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b35743568ac44060a46d69'),
#   'name': 'Barefoot Pinot Grigio',
#   'kind': 'wino',
#   'type': 'półwytrawne',
#   'description': 'Barefoot Pinot Grigio jest to białe, półwytrawne, kalifornijskie wino. Logo marki Barefoot odzwierciedla filozofię życiową założycieli, pełną optymizmu, ukierunkowaną na dobrą zabawę oraz realizowanie swoich pasji. W smaku tego wina możemy wyczuć nutkę cytryny oraz brzoskwini. Idealne do drobiu i owoców morza oraz pikantnych sosów.',
#   'country': 'USA',
#   'finish': [],
#   'aroma': ['cytryna', 'brzoskwinia'],
#   'taste': []},
#  {'_id': ObjectId('62b3576ff29d81f8393f8e52'),
#   'name': 'Dictador 12YO',
#   'kind': 'rum',
#   'type': 'złoty',
#   'description': 'Kolumbijski rum o bogatym zapachu i łagodnym smaku opakowany w elegancką ciemną matową butelkę. Przystępny w degustacji, doskonały nawet dla początkujących smakoszy trunku z Karaibów.',
#   'country': 'Kolumbia',
#   'finish': ['delikatny', 'wanilia'],
#   'aroma': ['wanilia', 'miód', 'orzechy'],
#   'taste': ['karmel', 'kakao', 'miód']},
#  {'_id': ObjectId('62b357eef29d81f8393f8e53'),
#   'name': 'Absolut Vodka',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Odważna, oryginalna i kreatywna. Absolut Vodka zadebiutowała w Nowym Jorku w 1979 roku. Nasza przezroczysta butelka pozbawiona etykiety, inspirowana wyglądem osiemnastowiecznych buteleczek z lekami, wyróżniała się na tle wysokich i krzykliwych produktów konkurencji. W końcu mówimy o Nowym Jorku z lat 70. Trzeba było się wyróżniać, aby być zauważonym. Inspiracja dzięki współpracy. Współpraca między Absolut a artystami i uczonymi była bezprecedensowym wydarzeniem. Po raz pierwszy rozpoczęliśmy współpracę z Andym Warholem w 1985 r. Sukces projektu „Absolut Warhol” zapoczątkował coś w rodzaju sztafety – pałeczka marki Absolut była od tego czasu przekazywana około 550 artystom. W „Spritmuseum” w Sztokholmie znajduje się obecnie ponad 850 dzieł sztuki – warto przyjechać, by je zobaczyć. Reklama na naszych zasadach. W przeciwieństwie do innych marek, które organizują głośne i mało wymyślne kampanie, my postanowiliśmy stworzyć coś subtelnego i powściągliwego, zgodnie z naszymi skandynawskimi korzeniami. Było to połączenie gier słownych w postaci wizualnej lub werbalnej z efektownymi obrazami, ze słynną sylwetką butelki umieszczoną gdzieś na reklamie. Z dumą możemy powiedzieć, że to najdłużej trwająca kampania marketingowa w historii reklamy. Ewolucja, nie rewolucja. Absolut Vodka nieustannie wyróżnia się unikatowym charakterem – zarówno w kwestii wzornictwa, jak i smaku. Zawsze interesujemy się kreatywnością, współpracą i sztuką. I nadal jesteśmy kluczowym składnikiem idealnych drinków na każdą okazję. A jako że wszystkie wódki marki Absolut są produkowane w południowej Szwecji, nasze wspaniałe produkty smakują dziś dokładnie tak samo jak dawniej. Nic się w tej kwestii nie zmieniło.',
#   'country': 'Szwecja',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b35875568ac44060a46d6a'),
#   'name': 'SAUVIGNON BLANC - SEMILLON, CIMAROSA',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Australijska kompozycja odmian Sauvignon Blanc i Sémillon. Trunek posiada przyjemny bukiet o charakterystyce owocowej, w którym wyróżniają się akcenty owoców mango, miechunki, kandyzowanego ananasa, brzoskwini i kwiatów jaśminu. Wino to polecamy do potraw z drobiu, smażonych ryb, warzywnej tarty lub zapiekanki.',
#   'country': 'Australia',
#   'finish': [],
#   'aroma': ['cytrusy'],
#   'taste': []},
#  {'_id': ObjectId('62b35892f29d81f8393f8e54'),
#   'name': 'Malibu Passion Fruit',
#   'kind': 'rum',
#   'type': 'biały',
#   'description': 'Malibu swietnie nadaje się do różnych drinków. Świeży, łagodny smak zamknięty w butelce. Najlepiej sprzedający się na świecie rum karaibski o smaku egzotycznej marakui.',
#   'country': 'hiszpania',
#   'finish': ['łagodny', 'słodki'],
#   'aroma': ['cukier trzcinowy', 'marakuja'],
#   'taste': ['słodki ', 'orzeźwiający', 'owoce egzotyczne', 'marakuja']},
#  {'_id': ObjectId('62b4391cd7995d801996d75f'),
#   'name': 'Jameson',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Jameson to jedna z najpopularniejszych irlandzkich whisky typu blended. Przedstawia świetne połączenie nut owocowych i orzechowych z akcentem drewna. Została wyprodukowana z połączenia whiskey zbożowej i whiskey typu pot still (destylowanej w alembiku). Destylowana trzykrotnie, by następnie dojrzewać co najmniej 4 lata w dębowych beczkach.',
#   'country': 'Irlandia',
#   'finish': ['gładki', 'słodki', 'pikantny'],
#   'aroma': ['nuty kwiatowe', 'owoce', 'nuty korzenne', 'drewno'],
#   'taste': ['nuty korzenne',
#    'orzechy',
#    'wanilia',
#    'słodkie sherry',
#    'łagodny']},
#  {'_id': ObjectId('62b4407ddd971448a4beeaeb'),
#   'name': 'Jameson Caskmates Stout Edition',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Efekt współpracy między destylarnią Jamesona z właścicielem browaru Franciscan Well w hrabstwie Cork. Została poddana procesowi dodatkowego dojrzewania w beckach, w których dojrzewało piwo stout. Łagodność uzyskiwana jest dzięki potrójnej destylacji. Charakteryzuje się wyczuwalnymi nutami kakao, kawy, karmelu oraz niezaprzeczalnym wpływem piwa stout.',
#   'country': 'Irlandia',
#   'finish': ['długi', 'słodki', 'mleczna czekolada', 'karmel'],
#   'aroma': ['nuty owocowe',
#    'jabłko',
#    'gruszka',
#    'nuty korzenne',
#    'orzechy',
#    'skórka limonki'],
#   'taste': ['mleczna czekolada', 'chmiel', 'kakao', 'marcepan']},
#  {'_id': ObjectId('62b4464cd7995d801996d760'),
#   'name': 'Chenin Blanc South Afrika',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': '',
#   'country': 'RPA',
#   'finish': [],
#   'aroma': ['cytrusy', 'jabłko', 'gruszka'],
#   'taste': []},
#  {'_id': ObjectId('62b44ad7d7995d801996d761'),
#   'name': "Jack Daniel's Old No. 7",
#   'kind': 'whisky',
#   'type': 'Tennessee whiskey',
#   'description': 'Każdy miłośnik whisky zetknął się kiedyś z tym trunkiem. To najpopularniejsza amerykańska whiskey produkowana od 1866 roku, kiedy to Jasper „Jack” Daniel zaufał swojej intuicji i postawił na stworzenie wysokiej jakości trunku. Łagodzona kropla po kropli przez 3 metry cukrowego węgla drzewnego klonowego, a następnie dojrzewa w ręcznie robionych beczkach własnej produkcji',
#   'country': 'USA',
#   'finish': ['drewno', 'wanilia', 'karmel', 'pieprz'],
#   'aroma': ['wanilia', 'kukurydza', 'orzechy', 'drewno'],
#   'taste': ['słodki', 'wanilia', 'pieprz', 'węgiel drzewny', 'karmel']},
#  {'_id': ObjectId('62b44c7ddd971448a4beeaed'),
#   'name': 'Costa Azul Shiraz',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Wytrawne wino o purpurowej barwie pochodzące z Hiszpani.',
#   'country': 'Hiszpania',
#   'finish': [],
#   'aroma': ['czarna porzeczka', 'czerwona porzeczka', 'śliwka', 'jeżyna'],
#   'taste': []},
#  {'_id': ObjectId('62b450d8dd971448a4beeaee'),
#   'name': "Jack Daniel's Gentleman Jack",
#   'kind': 'whisky',
#   'type': 'Tennessee whiskey',
#   'description': 'Zainspirowany oryginalnym gorzelnikiem, dżentelmenem i założycielem, Gentleman Jack poddaje się drugiemu zmiękczeniu węglem, aby uzyskać wyjątkową gładkość. Jej zrównoważony smak jest idealny do celebrowania niezwykłych okazji życia, a także wszystkich chwil po drodze. Pierwsza filtracja odbywa się przed dojrzewaniem destylatu w ręcznie robionych dębowych beczkach, druga zaś tuż przed rozlaniem gotowej whiskey do pięknych kwadratowych butelek. ',
#   'country': 'USA',
#   'finish': ['karmel', 'kukurydza', 'miód', 'węgiel drzewny'],
#   'aroma': ['cynamon', 'mleczna czekolada', 'kukurydza', 'węgiel drzewny'],
#   'taste': ['wanilia', 'karmel', 'pieprz', 'pieczone banany', 'miód']},
#  {'_id': ObjectId('62b45510d7995d801996d762'),
#   'name': 'Serpasso Duca di Sasseta',
#   'kind': 'wino',
#   'type': 'półwytrawne',
#   'description': 'Cierpkie półwytrawne wino z Włoch, idalnie nadaje się do mięs.',
#   'country': 'Włochy',
#   'finish': [],
#   'aroma': ['wiśnia', 'czereśnia', 'jeżyna'],
#   'taste': []},
#  {'_id': ObjectId('62b45543d7995d801996d763'),
#   'name': "Jack Daniel's Single Barrel Select",
#   'kind': 'whisky',
#   'type': 'Tennessee whiskey',
#   'description': 'To luksusowa whiskey dojrzewająca w warunkach wielkich zmian temperatury wpływających na niesamowity kolor i głębię smaku. Podobnie jak podstawowy Jack Daniel\'s, po zakończeniu starannej destylacji poddawany jest procesowi filtracji przez kolumnę węgla drzewnego. Podczas całego okresu dojrzewania whiskey  w wyżej wymienionych warunkach odparowuje nawet 30% drogocennego trunku - jest to tzw. ,,angel share", czyli udział aniołów w procesie tworzenia. Pochodzi zawsze z pojedynczych, ręcznie wybieranych beczek i stanowi przejaw olbrzymiego doświadczenia i wiedzy Master Blendera destylarni Jack Daniel\'s. Do podkreślenia indywidualnego charakteru whisky każda butelka oznaczona jest numerem beczki, z której pochodzi oraz datą jej rozlania.',
#   'country': 'USA',
#   'finish': ['mocny', 'drewno', 'wanilia'],
#   'aroma': ['karmel', 'pieprz', 'gruszka'],
#   'taste': ['wanilia', 'drewno', 'orzechy', 'marcepan']},
#  {'_id': ObjectId('62b4584cdd971448a4beeaef'),
#   'name': 'Dornfelder Halbtrocken',
#   'kind': 'wino',
#   'type': 'półwytrawne',
#   'description': 'Niemieckie czerwone wino, półwytrawne, łagodnie kwaskowe.',
#   'country': 'Niemcy',
#   'finish': [],
#   'aroma': ['truskawka', 'czereśnia', 'Wanilia'],
#   'taste': []},
#  {'_id': ObjectId('62b45aabd7995d801996d764'),
#   'name': 'Jim Beam',
#   'kind': 'whisky',
#   'type': 'bourbon',
#   'description': 'Jim Beam Kentucky Straight Bourbon Whiskey to najsławniejszy i najpopularniejszy bourbon świata. Nie ma chyba nikogo, kto nie zna tej whiskey – podstawowy, czteroletni, wypust destylarni Jim Beam, który stanowi także trzon portfolio marki. Elegancki. Łagodny. Wyrafinowany. Przez 4 lata bourbon dojrzewa w beczkach z amerykańskiego białego dębu. To właśnie to nadaje mu wyjątkową jakość. Każda kropla wytwarzana jest zgodnie z recepturami stworzonymi przez pradziadków rodziny Beam. Każda kropla jest warta wysiłku.',
#   'country': 'USA',
#   'finish': ['wanilia', 'miód', 'orzechy', 'pieprz'],
#   'aroma': ['kukurydza', 'cynamon', 'drewno', 'karmel', 'lukrecja'],
#   'taste': ['słodki', 'opalone drewno', 'owoce', 'wanilia', 'kukurydza']},
#  {'_id': ObjectId('62b466f2aa6a49ac4e1bd3f4'),
#   'name': "Jim Beam Devil's Cut",
#   'kind': 'whisky',
#   'type': 'bourbon',
#   'description': 'Wydobywany ekstrakt z dębowych beczek jest mieszamy z ekstra dojrzałą Kentucky whiskey. Tak powstaje bourbon prawdziwej klasy premium. Podczas procesu leżakowania, pewna ilość destylatu zostaje uwięziona w dębowym drewnie beczki. Devil’s Cut powstaje dzięki odzyskiwaniu destylatu z drewna i wymieszaniu go z dojrzałą wcześniej whisky. ',
#   'country': 'USA',
#   'finish': ['drewno', 'karmel', 'cynamon', 'pieprz', 'imbir'],
#   'aroma': ['drewno', 'kukurydza', 'wanilia', 'suszone owoce', 'karmel'],
#   'taste': ['słodki', 'orzechy', 'cynamon', 'karme', 'drewno']},
#  {'_id': ObjectId('62b4796daa6a49ac4e1bd3f5'),
#   'name': 'Jim Beam Double Oak',
#   'kind': 'whisky',
#   'type': 'bourbon',
#   'description': 'Jim Beam Double Oak to synonim nowej jakości dojrzewania bourbona. Wszystko zaczyna się od klasycznego Jim Beam’a, który leżakuje 4 lata. Następnie alkohol przelewany jest do świeżo palonej beczki, w której dojrzewa kolejne lata. Drugie beczkowanie pozwala na wytworzenie się jeszcze głębszej, lekko korzennej, dębowej nuty oraz aromatu bogatego w karmel.',
#   'country': 'USA',
#   'finish': ['czekolada', 'drewno', 'pieprz', 'wanilia'],
#   'aroma': ['wanilia', 'karmel', 'toffi', 'drewno', 'migdały'],
#   'taste': ['słodki', 'dym', 'karmel', 'drewno', 'czekolada']},
#  {'_id': ObjectId('62b47db4aa6a49ac4e1bd3f6'),
#   'name': 'Johnnie Walker Black Label',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Mistrzowska mieszanka whisky single malt i zbożowych z całej Szkocji, leżakowana przez co najmniej 12 lat. Rezultatem jest ponadczasowy klasyk o głębi i równowadze smaku. Pij z lodem, w czystej postaci lub w Highballu.',
#   'country': 'Szkocja',
#   'finish': ['dym', 'karmel', 'czekolada'],
#   'aroma': ['owoce', 'wanilia', 'pieprz'],
#   'taste': ['toffi', 'słodki', 'owoce', 'drewno']},
#  {'_id': ObjectId('62b48012c01face304ddea66'),
#   'name': 'Johnnie Walker Red Label',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': "Wśród koneserów budzi kontrowersje ze względu na popularność i przypisywanie jej cech mainstrem'owego trunku. Flagowa marka producenta Diageo. Stworzona do mieszania, zarówno w ekscytujących koktajlach, jak i z ulubionymi ludźmi. Łączy whisky specjalnie wybrane ze względu na ich odważne, żywe smaki, które dodają ognistego kopa każdej mieszance.",
#   'country': 'Szkocja',
#   'finish': ['dym', 'toffi'],
#   'aroma': ['cytrusy', 'owoce', 'karmel'],
#   'taste': ['cynamon', 'pieprz', 'karmel']},
#  {'_id': ObjectId('62b48352c01face304ddea67'),
#   'name': 'Johnnie Walker Gold Label Reserve',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Ta wielokrotnie nagradzana szkocka jest wytwarzana z whisky wybranych ze względu na ich słodkie, miodowe właściwości. Wybieramy je, gdy są najbardziej żywe, aby uzyskać wyrazisty smak w każdym kęsie. Model ten nazywany jest często szampanem wśród whisky. Jego głównym składnikiem jest Clynelish (single malt) do produkcji, której stosuje się wodę ze źródeł wypływających ze wzgórz Kildonan Hills, w których w 1868 r. odkryto pokłady złota. Johnnie Walker Gold Label Reserve dedykowana jest do celebrowania wyjątkowych, "złotych" chwil w życiu.',
#   'country': 'Szkocja',
#   'finish': ['słodki', 'dym', 'toffi'],
#   'aroma': ['miód', 'drewno', 'karmel', 'pomarańcze'],
#   'taste': ['owoce', 'wanilia', 'morele', 'cynamon']},
#  {'_id': ObjectId('62b4854ac01face304ddea68'),
#   'name': 'Johnnie Walker Blue Label',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Johnnie Walker Blue Label pochodzi z ręcznie selekcjonowanych rzadkich szkockich whisky o niezwykłej głębi smaku. Tylko jedna na 10 000 beczek przechodzi selekcję. Najlepiej podawać w czystej postaci, wraz z lodowatą wodą, aby wzmocnić jego mocny charakter.',
#   'country': 'Szkocja',
#   'finish': ['dym', 'drewno', 'owoce'],
#   'aroma': ['wanilia', 'miód', 'rodzynki'],
#   'taste': ['karmel', 'czekolada', 'orzechy']},
#  {'_id': ObjectId('62b487c8c01face304ddea69'),
#   'name': 'Johnnie Walker Green Label',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Jedyna szkocka marki Johnnie Walker mieszana w całości z single maltami. Johnnie Walker Green Label to ukryty klejnot z żywymi sekretami do ujawnienia. A dzięki słodom z czterech zakątków Szkocji, dojrzewającym przez co najmniej 15 lat, oddaje w idealnej równowadze wyraziste smaki każdego krajobrazu. Whisky w zgodzie z naturą.',
#   'country': 'Szkocja',
#   'finish': ['drewno', 'czekolada', 'owoce'],
#   'aroma': ['trawa', 'kwiaty', 'owoce', 'cytrusy'],
#   'taste': ['dym', 'nuty korzenne', 'słodki']},
#  {'_id': ObjectId('62b488965aff740017de6854'),
#   'name': 'Viura,Airen Valdepenas',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Łączące dwie odmiany hiszpańskie wino, które jest wytrawne i kwaskowe. Pasuje do owoców morza i ryb.',
#   'country': 'Hiszpania',
#   'finish': [],
#   'aroma': ['owoce tropikalne', 'jogurt', 'ciasto drożdzowe'],
#   'taste': []},
#  {'_id': ObjectId('62b489625aff740017de6855'),
#   'name': 'Portal do Minho Branco',
#   'kind': 'wino',
#   'type': 'półwytrawne',
#   'description': 'Wieloszczepowe portugalskie białe wino półwytrane. Niesamowicie ożeźwiające, ze znakomitą równowagą smaków.',
#   'country': 'Portugalia',
#   'finish': [],
#   'aroma': ['owoce tropikalne', 'cytryna', 'jabłko'],
#   'taste': []},
#  {'_id': ObjectId('62b48a187c93cafdd7d0944a'),
#   'name': 'Portal do Minho Loureiro ',
#   'kind': 'wino',
#   'type': 'półwytrawne',
#   'description': 'Ożeźwiające białe wino. Pochodzi z Portugalii z rejonu Mihno.',
#   'country': 'Portugalia',
#   'finish': [],
#   'aroma': ['cytrusy', 'jabłko'],
#   'taste': []},
#  {'_id': ObjectId('62b48a687c93cafdd7d0944b'),
#   'name': 'Chevalier de Fauvert Merlot',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'To francuskie wino zaskakuje ciekawymi aromatami śliwek i malin. Idealnie pasuje do obiadu zawierającego kaczkę.',
#   'country': 'Francja',
#   'finish': [],
#   'aroma': ['śliwka', 'czarna porzeczka', 'wanilia', 'malina'],
#   'taste': []},
#  {'_id': ObjectId('62b48ad87c93cafdd7d0944c'),
#   'name': 'Vineris Bordeaux',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Wino z Bordeaux, wytrawne i umiarkowanie cierpkie. Jest doskonałym kompanem dziczyzny na stole.',
#   'country': 'Francja',
#   'finish': [],
#   'aroma': ['czarna porzeczka', 'śliwka', 'czekolada'],
#   'taste': []},
#  {'_id': ObjectId('62b48b185aff740017de6856'),
#   'name': "Ballantine's 12yo",
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Wyrafinowana mieszanka whisky wyselekcjowanych w szczytowym momencie dojrzewania. Połączona w trunek będący efektem pasji do tego rzemiosła. Jest to whisky z miodową słodyczą, doskonale zrównoważoną nutami dębu i wanilii. Jest to whisky dla cierpliwych, którzy nie mogą się doczekać, kiedy znów będą się nią delektować. Ballantine’s 12 została stworzona z pasją do whisky dla tych, którzy pasjonują się whisky.',
#   'country': 'Szkocja',
#   'finish': ['słodki', 'orzechy', 'wanilia', 'miód'],
#   'aroma': ['miód', 'drewno', 'wanilia'],
#   'taste': ['miód', 'nuty kwiatowe']},
#  {'_id': ObjectId('62b491167c93cafdd7d0944d'),
#   'name': "Ballantine's Finest",
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': "Ballantine's Finest to whisky typu Blended o złożonym i eleganckim smaku, leżakująca minimum 3 lata, a w wielu przypadkach znacznie dłużej. Charakterystyczna, jasnozłota barwa oraz niezapomniany smak to efekt połączenia różnych whisky słodowych i zbożowych. Smak dwóch głównych destylatów - whisky słodowych z Miltonduff oraz Glenburgie sprawia, że Ballantine's Finest pobrzmiewa nutami czekolady, jabłek i wanilii.",
#   'country': 'Szkocja',
#   'finish': ['nuty kwiatowe', 'owoce'],
#   'aroma': ['miód', 'nuty korzenne', 'toffi'],
#   'taste': ['mleczna czekolada', 'jabłka', 'wanilia']},
#  {'_id': ObjectId('62b493935aff740017de6857'),
#   'name': 'Monkey Shoulder',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Monkey Shoulder jest zakorzenione w historii whisky słodowej i zainspirowane przez rzemieślników, którzy wciąż ręcznie przetwarzają słodowany jęczmień. Jest mieszany z małymi partiami najlepszych whisky single malt ze Speyside. Monkey Shoulder to 100% whisky słodowa, stworzona do mieszania. Jego bogactwo i żywiołowość łączą się z owocowymi aromatami i łagodnymi nutami wanilii.',
#   'country': 'Szkocja',
#   'finish': ['pomarańcze', 'wanilia', 'drewno'],
#   'aroma': ['owoce', 'karmel', 'miód', 'mleczne krówki'],
#   'taste': ['słodki', 'jabłka', 'gruszki', 'miód']},
#  {'_id': ObjectId('62b493a47c93cafdd7d0944e'),
#   'name': 'Montebuena Rioja Alavesa',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Hiszpańskie wino o rubinowym kolorze. Cechuje się aromatem beczki, czarnej porzeczki i jagód. Idealne do mięs',
#   'country': 'Hiszpania',
#   'finish': [],
#   'aroma': ['czarna porzeczka', 'jagody'],
#   'taste': []},
#  {'_id': ObjectId('62b494eb5aff740017de6858'),
#   'name': 'Witosha Premium Sweet Red',
#   'kind': 'wino',
#   'type': 'słodkie',
#   'description': 'Witosha Premium Sweet Red  to czerwone, słodkie, bułgarskie wino deserowe. Wino ma podwyższoną zawartość alkoholu ( 17% ) oraz wyrazisty, owocowy, słodki smak.',
#   'country': 'Bułgaria',
#   'finish': [],
#   'aroma': ['cytrusy', 'suszona truskawka'],
#   'taste': []},
#  {'_id': ObjectId('62b495a65aff740017de6859'),
#   'name': 'Amundsen',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Amundsen Vodka to niezwykle delikatna wódka produkowana w Polsce na norweskiej licencji. Swój unikalny smak zawdzięcza krystalicznie czystej wodzie, z której jest stworzona oraz powolnemu procesowi rektyfikacji.  To najzimniejsza na rynku wódka, którą podawać należy w temperaturze ok. zera st. C. Swoje walory odkryje tuż przed zamrożeniem, schłodzona do 0 stopni Celsjusza. Tak podana wydobywa wszystkie swoje walory. Dzikość, surowość i mocny smak. Wszystko to, co charakteryzuje męski świat niecodziennych wyzwań i niesamowitych przygód. Bo każdy mężczyzna przecież ma w sobie pierwiastek odkrywcy, wystarczy go tylko odnaleźć w sobie i rzucić się w krąg przygody. Być może podobnej do tej sprzed ponad 100 lat, kiedy po raz pierwszy na Antarktydzie stanęła ludzka stopa. To klucz do niezwykłego męskiego świata. Zdrowej rywalizacji i pokonywania własnych biegunów.  Antarktyda - świat skuty lodem, nieskażony i pierwotny fascynuje do dziś. Krystaliczna czystość południowego bieguna i jej lodowy krajobraz budzi respekt i szacunek. Stał się inspiracją nie tylko do wytworzenia zimnego krystalicznego alkoholu. Także butelka dedykowana tej wódce została zaprojektowana tak, by oddać jej nieskazitelną jakość i temperaturę. Łatwo pomylić ją z lodową rzeźbą, wyjętą wprost z zamarzniętej tafli. Doskonale współgra z zamkniętą w niej  zawartością - ekstremalnie czystą wódką stworzoną z uważnie wyselekcjonowanych składników.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b495c27c93cafdd7d0944f'),
#   'name': 'Glenfiddich 12yo',
#   'kind': 'whisky',
#   'type': 'single malt',
#   'description': 'Starannie dojrzewa w beczkach po sherry z najlepszych amerykańskich i europejskich dębów przez co najmniej 12 lat, a następnie dojrzewa w dębowych kadziach ślubnych, aby uzyskać słodki i subtelny smak dębu. Kremowy z długim, gładkim i aksamitnym wykończeniem, ten 12-latek jest doskonałym przykładem unikalnego stylu Speyside Glenfiddich i jest powszechnie uznawany za najlepszą whisky w dolinie jelenia.',
#   'country': 'Szkocja',
#   'finish': ['kremowy', 'pieprz'],
#   'aroma': ['jabłka', 'nuty kwiatowe', 'wanilia', 'cytrusy'],
#   'taste': ['jabłka', 'cytrusy', 'drewno']},
#  {'_id': ObjectId('62b496737c93cafdd7d09450'),
#   'name': 'Barmańska Pigwa',
#   'kind': 'wódka',
#   'type': 'owocowa',
#   'description': 'Inspiracją do powstania Barmańskiej był smak dojrzałych soczystych owoców. Dzięki temu powstała receptura z udziałem soku z pigwy, która sprawia, że Barmańska zaskakuje owocową świeżością. Wyjątkowe walory wynikają z idealnie dobranych proporcji alkoholu i pigwowego smaku. Najlepiej podawać schłodzoną lub z kostkami lodu.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['pigwowy'],
#   'taste': ['pigwowy']},
#  {'_id': ObjectId('62b496a27c93cafdd7d09451'),
#   'name': 'Merlot - Touriga Nacional',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Wino o kolorze rubinowym, o intensywnym aromacie agrestu i pomarańczy. Nadaje się idealnie do makaronów i dań z kurczakiem',
#   'country': 'Portugalia',
#   'finish': [],
#   'aroma': ['agrest', 'pomarańcz', 'kawa', 'wanilia'],
#   'taste': []},
#  {'_id': ObjectId('62b49a0b5aff740017de685e'),
#   'name': 'Baileys Salted Caramel ',
#   'kind': 'likier',
#   'type': 'irlandzki',
#   'description': 'Nie nalezy mieszać z napojami na bazie owoców cytrusowych. Kolejny, urzekający profil likieru Baileys, który oferuje pyszny smak solonego karmelu. Ukazał się na rynku z myślą o zbliżających się świętach Bożego Narodzenia. Jego twórcy wyobrazili sobie siebie samych siedzących przed kominkiem z kieliszkiem rozgrzewającego podniebienie Baileysa i słuchających rodzinnych opowieści lub oglądających ulubione seriale.',
#   'country': 'Irlandia',
#   'finish': ['łagodny'],
#   'aroma': ['czekolada'],
#   'taste': ['whiskey', 'czekolada', 'słony karmel']},
#  {'_id': ObjectId('62b49a2f5aff740017de685f'),
#   'name': 'Astrale Rosso',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Wino o głębokiej purpurowej barwie z jasnymi refleksami i bogatym aromacie z wyczuwalną kompozycją dojrzałych czerwonych owoców i delikatnych przypraw.',
#   'country': 'Włochy',
#   'finish': [],
#   'aroma': ['śliwka', 'wanilia', 'czarna porzeczka', 'wiśnia'],
#   'taste': []},
#  {'_id': ObjectId('62b49aa25aff740017de6860'),
#   'name': 'Biały Bocian',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Biały Bocian to Polska wódka premium. Posiada unikalny zestaw składników, dzięki czemu jest oryginalna i wyrafinowana. Jest to typ wódki Gluten Free. Pochodzi z wielkopolskich zbóż, każdy składnik jest dobrze dopracowany, dzięki czemu posiada tak wyrazisty smak. Jest delikatna i subtelna.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b49af47c93cafdd7d09457'),
#   'name': 'Glenfiddich 15yo',
#   'kind': 'whisky',
#   'type': 'single malt',
#   'description': 'Leżakowana w europejskich dębowych beczkach po sherry i nowych dębowych beczkach, whisky jest zmiękczana w naszym wyjątkowym Solera Vat, dużej dębowej kadzi inspirowanej winiarnią sherry z Hiszpanii i Portugalii. Nigdy nie opróżniana i przechowywana w połowie pełna od 1998 roku, kadź Solera jest zwieńczeniem ciekawskich umysłów i pionierskiego ducha rodziny Grants. To także powód tego, że ta whisky została pierwszym 15-latkiem, który znalazł się w pierwszej dziesiątce najlepiej sprzedających się single maltów.',
#   'country': 'Szkocja',
#   'finish': ['wanilia', 'cynamon', 'goździki', 'drewno'],
#   'aroma': ['sherry', 'miód', 'karmel', 'mleczna czekolada', 'wanilia'],
#   'taste': ['sherry', 'marcepan', 'cynamon', 'imbir', 'miód']},
#  {'_id': ObjectId('62b49b665aff740017de6861'),
#   'name': 'Bols Vodka',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Czysta wódka produkowana z wykorzystaniem nowatorskich metod- w procesie rektyfikacji wykorzystuje się unikatową hydroselekcję, pozwalającą uzyskać spirytus o charakterze neutralnego, poddawanego następnie wielokrotnej filtracji i uszlachetnianiu, sam zaś spirytus jest wytwarzany u producentów spełniających wysokie wymagania technologiczne - pod stałą kontrolą i nadzorem jakości firmy Bols. Bols to holenderska marka wódki, istniejąca od 1575 r. co upamiętnia herb na etykiecie alkoholu. W Polsce produkowana jest od 1994 r. Wódka Bols została wyróżniona w 2010 r. prestiżowym tytułem "Wyjątkowej" przez Jury International Taste & Quality Institute- w konkursie Superior Taste Award alkohole analizowane były między innymi pod względem pierwszego wrażenia, smaku i zapachu. We wszystkich tych kategoriach otrzymała bardzo wysokie noty, co zaowocowało przyznaniem BOLS Premium Vodka najwyższej nagrody trzech gwiazdek, uzyskując miano "Exceptional - Wyjątkowej". Formuła testu zakłada degustację produktów bez ich identyfikacji z marką czy opakowaniem, przez wieloosobową, międzynarodową komisję, co pozwala potwierdzić rzeczywistą jakość trunku bez wpływów marki. Wszystkie warianty wódki BOLS produkowane są w jednym z najnowocześniejszych zakładów rektyfikacyjnych na świecie w Obornikach Wielkopolskich.Wódka jest tam poddawana 4-krotnemu procesowi destylacji oraz filtracji węglowo-miedziowej, dzięki temu jej czystość przewyższa aż 5-krotnie restrykcyjne unijne normy. To sprawia, że ma niezwykle łagodny smak i zapach, pozostawiając na podniebieniu wyczuwalną esencję wódki najwyższej jakości.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b49c927c93cafdd7d0945a'),
#   'name': 'Chopin',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Chopin Rye to wódka wywodząca się z polskiego Podlasia. Wytwarzana jest w legendarnym Polmosie Siedlce z najwyższej jakości żyta. Proces wytwarzania wódki Chopin jest bardzo podobny do metod stosowanych przed laty. Wódka nie zawiera żadnych dodatków, a jej sekret tkwi w prostocie produkcji oraz odpowiedniej selekcji składników. Chopin Rye charakteryzuje się delikatnym choć bogatym i zrównoważonym smakiem z odrobinę pikantnym finiszem oraz wyraźnym aromatem żytniego chleba z lekko surową nutą.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b49cf07c93cafdd7d0945b'),
#   'name': 'Tullamore D.E.W.',
#   'kind': 'whisky',
#   'type': 'blended',
#   'description': 'Tullamore D.E.W. to oryginalna irlandzka whiskey typu triple blend znana na całym świecie ze swojej delikatnej i łagodnej głębi. Złożone, ale przystępne smaki whiskey biorą się z trzech rodzajów ziarna, potrójnej destylacji i połączenia trzech rodzajów irlandzkiej whiskey. Przez okres kilku lat dojrzewa w tradycyjnych uprzednio używanych beczkach, beczkach po burbonie i beczkach po sherry.',
#   'country': 'Irlandia',
#   'finish': ['nuty korzenne', 'drewno'],
#   'aroma': ['owoce', 'karmel', 'drewno'],
#   'taste': ['słodki', 'karmel', 'czekolada']},
#  {'_id': ObjectId('62b49d5f7c93cafdd7d0945c'),
#   'name': 'Monte da Ravasqueira, Superior Tinto',
#   'kind': 'wino',
#   'type': 'wytrawne',
#   'description': 'Wino o głębokim purpurowym kolorze o silnym aromacie beczki oraz owoców. Idealne do mięs.',
#   'country': 'Portugal',
#   'finish': [],
#   'aroma': ['aromat beczki', 'śliwka', 'czarna porzeczka'],
#   'taste': []},
#  {'_id': ObjectId('62b49d865aff740017de6862'),
#   'name': 'Beefeater London',
#   'kind': 'gin',
#   'type': 'destylowany',
#   'description': 'Produkowany w niezmienny szlachetny sposób z wielką wprawą i z 9 najlepszych ręcznie wybranych ziół.',
#   'country': 'Londyn',
#   'finish': ['średnio długi', 'jałowiec'],
#   'aroma': ['jałowiec', 'cytrusy', 'lukrecja'],
#   'taste': ['mocny', 'wyrazisty', 'jałowiec', 'cytrusy']},
#  {'_id': ObjectId('62b49dd57c93cafdd7d0945d'),
#   'name': 'Finlandia',
#   'kind': 'wódka',
#   'type': 'czysta',
#   'description': 'Wódka Finlandia jest produkowana z uprawianego w Finlandii sześciorzędowego jęczmienia i czystej wody źródlanej z lodowca. Woda jest naturalnie filtrowana przez moreny, pozostałe po zejściu lodowca tysiące lat temu, dlatego wódka nie potrzebuje żadnej filtracji, ani innego sztucznego oczyszczania — w przeciwieństwie do niektórych innych wódek. Składniki te nadają wódce wytrawny, lekki i gładki smak oraz delikatny aromat.',
#   'country': 'Finlandia',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('62b49ef45aff740017de6863'),
#   'name': 'Gianduia Bottega',
#   'kind': 'likier',
#   'type': 'mleczny',
# ...
#   'type': 'Oatmeal Stout',
#   'description': 'Tradycyjnie owsiany, wyjątkowo smaczny. Jak zawsze warzony w kreatywnym uniesieniu.\nSkładniki: woda, słody jęczmienne: Pale Ale, karmelowy 600EBC, czekoladowy ciemny, barwiący obłuszczony; słody pszeniczne: pszeniczny jasny, płatki owsiane, chmiel polski; drożdże górnej fermentacji.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['czekolada', 'chmiel'],
#   'taste': ['czekolada', 'karmel', 'chmiel']},
#  {'_id': ObjectId('6366abb607b90e3194d4ae70'),
#   'name': 'Wrężel Obibock',
#   'kind': 'piwo',
#   'type': 'Maibock',
#   'description': 'Kto powiedział, że z kanapy nie można uratować świata? Piwo jasne w stylu koźlak majowy o delikatnie słodowym aromacie. Składniki: woda; słody jęczmienne: Pilzneński, Wiedeński, Monachijski ciemny, Karmelowy 400; chmiel: Columbus (USA); drożdże Fermentis S-189.',
#   'country': 'Polska',
#   'finish': ['goryczka'],
#   'aroma': ['karmel'],
#   'taste': ['karmel', 'słód']},
#  {'_id': ObjectId('6366ad438d73c583ea534da4'),
#   'name': 'Wrężel BOWMORE',
#   'kind': 'piwo',
#   'type': 'peated bis barrel aged',
#   'description': 'Russian Imperial Stout, lekko palone, z torfowymi nutami pochodzącymi od wędzonego słodu, poddane procesowi leżakowania w dębowej beczce po whisky ze szkockiej destylarni Bowmore.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['czekolada', 'chmiel'],
#   'taste': ['karmel', 'czekolada', 'chmiel']},
#  {'_id': ObjectId('6366aea28d73c583ea534da5'),
#   'name': 'Wrężel Peated RIS Buffalo Trace Barrel Aged',
#   'kind': 'piwo',
#   'type': 'Peated RIS BA',
#   'description': 'Czarne złoto browarnictwa w torfowych nutach wędzonego słodu. Leżakowane w beczce po whisky Buffalo Trace.\nPiwo ciemne, pasteryzowane, niefiltrowane.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['whisky'],
#   'taste': ['czekolada', 'whisky']},
#  {'_id': ObjectId('6366af518d73c583ea534da6'),
#   'name': 'Wrężel Peated RIS Heaven Hill Barrel Aged',
#   'kind': 'piwo',
#   'type': 'Peated RIS BA',
#   'description': 'Mocne, esencjonalne, rozgrzewające, lekko palone, z torfowymi nutami pochodzącymi od wędzonego słodu, poddane procesowi leżakowania w dębowych beczkach wspaniałej whisky Heaven Hill.\nSKŁADNIKI: woda; słody jęczmienne: Château Whisky, Monachijski typ I, czekoladowy ciemny, karmelowy 300, barwiący; płatki błyskawiczne: płatki owsiane, herbata Lapsang (wędzona korzeniami bambusa); chmiel amerykański: Columbus; drożdże: S-04',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['czekolada'],
#   'taste': ['czekolada']},
#  {'_id': ObjectId('6366b0de07b90e3194d4ae71'),
#   'name': 'Wrężel Tropical Wild Bowmore BA',
#   'kind': 'piwo',
#   'type': 'Brett IPA BA',
#   'description': 'Edycja limitowana piwa wydana z okazji 5 urodzin browaru. Zostało ono poddane dodatkowej fermentacji drożdżami Amalagamation Brett Super Blend THE YEAST BAY i leżakowane w beczce po whisky.',
#   'country': 'Polska',
#   'finish': ['goryczka'],
#   'aroma': ['karmel', 'whisky', 'miód'],
#   'taste': ['karmel', 'miód', 'whisky']},
#  {'_id': ObjectId('6366b22707b90e3194d4ae72'),
#   'name': 'Wrężel Tropical IPA',
#   'kind': 'piwo',
#   'type': 'Imperial IPA',
#   'description': 'Piwo uwarzone przez Browar Wrężel z miejscowości Zarzecze (powiat żywiecki, województwo śląskie).\n\nTropikalna wersja Imperialnej IPA – maksymalnie goryczkowa, maksymalnie owocowa, maksymalnie aromatyczna. Dla Ciebie połączyliśmy smak tropikalnych owoców i najbardziej aromatyczne gatunki chmielu zza wielkiej wody. W tym piwie znajdziesz wszystko co potrzebne aby poczuć się jak w raju. Nie zastanawiaj się dłużej! Łap za butelkę!',
#   'country': 'Polska',
#   'finish': ['goryczka'],
#   'aroma': ['mango', 'pomarańcz', 'kokos'],
#   'taste': ['mango', 'pomarańcz', 'kokos']},
#  {'_id': ObjectId('6366b2f207b90e3194d4ae73'),
#   'name': 'Wrężel Sail On',
#   'kind': 'piwo',
#   'type': 'American IPA',
#   'description': 'Produkt browaru kontraktowego Wrężel, który swoje piwa warzy w Browarze Zarzecze. Browar Wrężel powstał stosunkowo niedawno, AIPA jest piątym piwem z tego browaru, które pojawiło się na rynku. Jest to piwo pasteryzowane i niefiltrowane w stylu American India Pale Ale. Marzy Ci się wyprawa do Stanów Zjednoczonych? Polecamy AIPA. To uczta dla nosa! W jednej butelce można znaleźć zarówno zapach żywicznego lasu, jak i owoców Florydy. Ale nie daj się zwieść oszałamiającym cytrusowym aromatom... Pod ich osłoną czai się mocne uderzenie goryczki! Życzymy Smacznego!!!',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['karmel', 'cytrusy', 'chmiel', 'żywica'],
#   'taste': ['karmel', 'cytrusy', 'chmiel']},
#  {'_id': ObjectId('6366b3b007b90e3194d4ae74'),
#   'name': 'Wrężel Ricer',
#   'kind': 'piwo',
#   'type': 'Rice DDH IPA',
#   'description': 'Uwarzone przez Browar Wrężęl.\nPiwo w styli Rice DDH IPA.\nPiwo jasne, pasteryzowane, niefiltrowane.\nSkład: woda, słody jęczmienne (Pilzneński, Carapils), płatki ryżowe, chmiele amerykańskie, drożdże.',
#   'country': 'Polska',
#   'finish': ['goryczka'],
#   'aroma': ['chmiel', 'owoce'],
#   'taste': ['chmiel', 'owoce']},
#  {'_id': ObjectId('6366b45d07b90e3194d4ae75'),
#   'name': 'Wrężel Rabarbest',
#   'kind': 'piwo',
#   'type': 'Gose',
#   'description': 'Piwo jasne o wyraźnie słonym smaku z dodatkiem soku z rabarbaru i agrestu.\n\nSkład :\nWODA; SŁODY PSZENICZNE: pszeniczny jasny; SŁODY JĘCZMIENNE: Pilzneński; CHMIEL: Chinook ; KOLENDRA INDYJSKA; SÓL MORSKA; SOK Z RABARBARU; SOK Z AGRESTU; KWAS MLEKOWY; DROŻDŻE: WB-06',
#   'country': 'Polska',
#   'finish': ['goryczka'],
#   'aroma': ['rabarbar', 'agrest'],
#   'taste': ['rabarbar', 'agrest', 'słony']},
#  {'_id': ObjectId('6366b59007b90e3194d4ae76'),
#   'name': 'Wrężel Pink Panther',
#   'kind': 'piwo',
#   'type': 'Weizen',
#   'description': 'W duszy wrężelą ci owocowe aromaty? Łap miks pszenicy i różowej gujawy. Zaskoczy cię swoją wyważoną słodyczą.',
#   'country': 'Polska',
#   'finish': ['gujawa'],
#   'aroma': ['banany', 'goździki', 'gujawa'],
#   'taste': ['drożdże', 'banany', 'goździki', 'gujawa']},
#  {'_id': ObjectId('6366b8778d73c583ea534da7'),
#   'name': 'Wrężel Pils',
#   'kind': 'piwo',
#   'type': 'Pils',
#   'description': 'Piwo jasne, o klasycznym, nieskomplikowanym smaku',
#   'country': 'Polska',
#   'finish': ['goryczka'],
#   'aroma': ['zboże'],
#   'taste': ['zboże', 'skórka cytryny']},
#  {'_id': ObjectId('6366b92c8d73c583ea534da8'),
#   'name': 'Wrężel Peatland',
#   'kind': 'piwo',
#   'type': 'Peated Russian Imperial Stout',
#   'description': 'Upłynnione czarne złoto z torfowym aromatem wędzonego słodu. Mocne, esencjonalne, lekko wędzone piwo ciemne. Składniki: woda; słody jęczmienne: Château Whisky, Monachijski typ I, czekoladowy ciemny, karmelowy 300, barwiący; Płatki błyskawiczne: płatki owsiane, herbata Lapsang (wędzona korzeniami bambusa); chmiel amerykański: Columbus; drożdże: S-04. [opis z oficjalnej strony browaru]',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': ['torf'],
#   'taste': ['torf', 'słód']},
#  {'_id': ObjectId('6366dc5807b90e3194d4ae77'),
#   'name': 'Pinta Miesiąca Październik 2022 I Am Lubelski Dude',
#   'kind': 'piwo',
#   'type': 'Fresh Hop Pils Polish Variety',
#   'description': 'W 2022 roku wracamy do korzeni – odkrywając klasykę na nowo. Tym razem polski rarytas – pils uwarzony ze świeżymi szyszkami LUBELSKIEGO, SUPER-AROMATYCZNEGO chmielu, który może konkurować z najbardziej szlachetnymi odmianami. Wnosi do piwa nuty ziołowe, trawiaste, korzenne oraz nieco herbaty i wątki kwiatowe.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366dcb68d73c583ea534da9'),
#   'name': 'PINTA Jak w Dym',
#   'kind': 'piwo',
#   'type': 'Rauchbock',
#   'description': '\ufeff\ufeff\ufeff\ufeff\ufeff\ufeff\ufeffPierwszy polski Koźlak Podwędzany. Pokochaj albo rzuć! Jesienny eksperyment z Browaru PINTA - ciemne, gęste, przydymione piwo dla miłośników nowych wrażeń. Uwaga - zawiera słody wędzone dymem z buku i orzecha. Fermentowane z użyciem drożdży w temp. 9°C.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366ddac8d73c583ea534daa'),
#   'name': 'Pinta Imperator Bałtycki',
#   'kind': 'piwo',
#   'type': 'Baltic Porter',
#   'description': 'Porter Bałtycki - ciemny, mocny lager to piwowarski skarb Polski. W klasycznej wersji - o ekstrakcie ok. 20°Plato -warzony jest z powodzeniem przez kilka polskich browarów. Jako PINTA doceniamy wartość Portera Bałtyckiego ale po swojemu robimy krok naprzód. Przedstawiamy Imperatora Bałtyckiego - ciemnego giganta ze słodu i chmielu. PINTA Imperator Bałtycki - piwo od święta.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366ddeb8d73c583ea534dab'),
#   'name': 'Pinta Imperator Bałtycki Enigma & Nelson Sauvin',
#   'kind': 'piwo',
#   'type': 'Imperialny Porter Bałtycki',
#   'description': 'PINTA Imperator Bałtycki Enigma & Nelson Sauvin – Ciemny i mocny Imperialny Porter Bałtycki – w aromacie i smaku akcenty pumpernikla oraz winogron i owoców tropikalnych od odmian chmieli z Australii i Nowej Zelandii.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366de4d8d73c583ea534dac'),
#   'name': 'Pinta / Pays Flamand Król Lata - Roi de l Eté',
#   'kind': 'piwo',
#   'type': 'Hoppy Oatmeal Witbier',
#   'description': 'Drugi owoc współpracy kontraktowego browaru Pinta z francuskim Brasserie du Pays Flamand. Pierwszym piwem uwarzonym w tej kooperacji była Księżniczka Wiosny - Princesse de Printemps. Był to Spring Saison dostępny w butelkach o pojemności 0,75l. PINTA oraz Brasserie du Pays Flamand polecają gładkie orzeźwienie. Czy piliście kiedyś owsianego Witbiera? Wspólnie z Olivierem i Mathiew, naszymi kompanami z francuskiego Brasserie du Pays Flamand przygotowaliśmy autorską wersję lekkiego, cytrusowego, dobrze nachmielonego Witbiera. Króla Lata uwarzyliśmy wspólnie w Browarze Na jurze, w Zawierciu końcem kwietnia - dzień przed Warszawskim Festiwalem Piwa. 15% zasypu to płatki owsiane - po to aby piwo jeszcze bardziej gładko gasiło pragnienie Chmielenie francuskim Strisselspalterem i amerykańską Citrą. Pierwsza warka została rozlana wyłącznie do beczek - połowa pojechała do Francji, połowę rozesłaliśmy do polskich pubów. Kolejna warka jest już w przygotowaniu, więc Król Lata w butelce pojawi się jeszcze tego lata.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366dec88d73c583ea534dad'),
#   'name': 'Pinta Hop Pokus',
#   'kind': 'piwo',
#   'type': 'Black India Pale Ale',
#   'description': 'Dawniej nazwa tego browara to Hopus Pokus. Nowa, magiczna propozycja od browaru Pinta - Hopus Pokus. Piwo w stylu Black India Pale Ale, barwy ciemnobrązowej, ale stosunkowo przejrzyste. Wysycenie na poziomie wysokim, piana zaś średnia - beżowa i delikatna, pozostawia drobne ślady na szkle, a co ważne - utrzymuje się na około 0,5 cm do końca picia. Aromat bardzo intensywny, wyczuwalne są amerykańskie chmiele z owocami cytrusowymi oraz palone słody. W smaku dodatkowo pojawia się intensywna goryczka, której faktycznie można się spodziewać po 66 IBU. Piwo wydaje się dość skoncentrowane, ale przy tym przyjemnie pijalne. Zawartość alkoholu 6,3% zwyczajna dla tego typu piw, nie czuć jej podczas konsumpcji.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366df498d73c583ea534dae'),
#   'name': 'Pinta Sun Super',
#   'kind': 'piwo',
#   'type': 'Hazy Pale Ale',
#   'description': 'Piwo uwarzone przez Browar Pinta z Wieprza (województwo śląskie, powiat żywiecki).\n\nPINTA Sun Super - orzeźwiające, zmętnione od dodatku płatków owsianych i pszennych, chmielowe piwo w stylu Hazy Pale Ale.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366dfc207b90e3194d4ae78'),
#   'name': 'Pinta A`la Grodziskie',
#   'kind': 'piwo',
#   'type': 'Grodziskie',
#   'description': 'Oryginalne polskie, lekkie piwo górnej fermentacji. Piwo jasne, słomkowe dość mętne. Piana drobnoziarnista, niewysoka, znika dość szybko. Zapach drożdżowy. Subtelny smak dymionego słodu i intensywna goryczka chmielu lubelskiego, lekko kwaskowate.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366e02907b90e3194d4ae79'),
#   'name': 'Pinta Havana Stout',
#   'kind': 'piwo',
#   'type': 'Foreign Extra Stout',
#   'description': 'Uwarzone przez kontraktowy browar Pinta w Browarze na Jurze z Zawiercia, w ramach akcji Pinta Miesiąca. PINTA Miesiąca - specjalna akcja piwowarska - co miesiąc prezentujemy zupełnie nowe piwo. Eksperymentujemy z recepturami i surowcami, kooperujemy z pasjonatami z Polski i zagranicy. Przygotowujemy jednorazowo nie więcej niż 100 beczek - piwo dostępne jest wyłącznie w beczkach w pubach biorących udział w akcji. Nie wykluczamy, że piwa które wzbudzą pozytywne emocje będą warzone na większą skalę i będą w przyszłości dostępne w regularnej sprzedaży - w beczkach i butelkach. Premiera każdego piwa planowana jest w II połowie miesiąca - od lutego do grudnia. Nazwę oraz styl każdego nowego piwa ogłaszamy kilka dni przed premierą - informacji szukajcie m.in. na kalendarzach dostępnych w pubach serwujących PINTĘ Miesiąca.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366e0b807b90e3194d4ae7a'),
#   'name': 'Miłosław & Makłowicz ArcyIP',
#   'kind': 'piwo',
#   'type': 'Session Hazy IPA',
#   'description': 'Wybierz się na piwną podróż z Robertem Makłowiczem!\nBrowar Fortuna jako jedyny browar podejmuje współpracę z popularnym znawcą kulinarnym i podróżnikiem  Orzeźwiające piwo IPA z goryczką i nutą cytrusów – zbalansowany smak Promocja piwa z Robertem Makłowiczem – szerokie dotarcie do odbiorcy,  autor kanału YT z 455 tys. subskrybentów, propozycje foodpairingu, piwna edukacja Piwo pijalne, idealne również jako towarzysz potraw. Wyróżniająca kompozycja 5 chmieli, w tym nowe odmiany polskich chmieli od rodzimego plantatora Polish Hops. Receptura Browaru Fortuna z chmieleniem na zimno. 100% naturalne składniki',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('6366e10307b90e3194d4ae7b'),
#   'name': 'Pinta Dyniamit',
#   'kind': 'piwo',
#   'type': 'Pumpkin Ale',
#   'description': 'Szaleństwo w kolorze ciemnej pomarańczy. Sezonowa, jesienno-zimowa dyniowa PINTA to interpretacja amerykańskiej specjalności w stylu Pumpkin Ale. PINTA Dyniamit warzona jest z dużym dodatkiem pieczonej dyni, intensywnie ale naturalnie aromatyzowana cynamonem, goździkami i imbirem.',
#   'country': 'Polska',
#   'finish': [],
#   'aroma': [],
#   'taste': []},
#  {'_id': ObjectId('636c1c279e2dbf397a78556f'),
#   'name': 'Noteckie Bursztynowe',
#   'kind': 'piwo',
#   'type': 'pale lager',
#   'description': 'Ciemne pasteryzowane piwo, rżnięte, charakteryzujące się słodyczą i goryczką.',
#   'country': 'Polska',
#   'finish': ['słodycz', 'goryczka'],
#   'aroma': ['słodycz', 'goryczka'],
#   'taste': ['słodycz', 'goryczka']},
#  {'_id': ObjectId('636d5d442d96d511ed784cab'),
#   'name': 'Celtic Surprise One',
#   'kind': 'piwo',
#   'type': 'dry stout',
#   'description': 'Pora zawrężlić przygodny smak i przenieść się do płynącej piwem krainy zielonych pagórków. Wystarczy spróbować tego Dry Stoutu!',
#   'country': 'Polska',
#   'finish': ['wytrawny', 'czekolada', 'karmel', 'orzechy'],
#   'aroma': ['karmel', 'orzechy', 'czekolada'],
#   'taste': []},
#  {'_id': ObjectId('636d5e3c2d96d511ed784cac'),
#   'name': 'Celtic Surprise Two',
#   'kind': 'piwo',
#   'type': 'irish red ale',
#   'description': 'Kierunek podróży? Zielona Wyspa! Wrężluj ze smakiem czerwone piwo o przyjemnym lekkim aromacie słodowym i odkryj z nami tajemnice Irlandii!',
#   'country': 'Polska',
#   'finish': ['słód'],
#   'aroma': ['słód'],
#   'taste': ['słód']},
#  {'_id': ObjectId('636d668fc19903dd865984f2'),
#   'name': 'Cherry No.1',
#   'kind': 'piwo',
#   'type': 'cherry barley wine',
#   'description': 'Rozsmakuj się w mocnym, tradycyjnie uwarzonym piwie z dodatkiem soku z wiśni. Mocne, esencjonalne, słodowe piwo jasne z dodatkiem soku z wiśni.',
#   'country': 'Polska',
#   'finish': ['wiśnia', 'słód'],
#   'aroma': ['wiśnia', 'słód'],
#   'taste': ['wiśnia', 'słód']}]

# %%
documents = []
num_topics
# Out:
# 244

# %%
nlp = spacy.load("pl_core_news_lg")
docs = nlp.pipe(items_data)

# %%
for doc in docs:
    documents.append([token.lemma_ for token in doc if (not token.is_stop and not token.is_punct)])

# %%
documents
# Out:
# [['jägermeister',
#   'likier',
#   'Ziołowy',
#   'skład',
#   'likier',
#   'jägermeister',
#   'niemal',
#   'sto',
#   'rok',
#   'utrzymywać',
#   'tajemnica',
#   'wiadomo',
#   'etykieta',
#   'likier',
#   'zawierać',
#   '56',
#   'zioło',
#   'przyprawa',
#   'rok',
#   'niezmiennie',
#   'budować',
#   'smak',
#   'aromat',
#   'trunek',
#   'imbir',
#   'skórka',
#   'cytrus',
#   'ziołowy',
#   'imbir',
#   'goździk',
#   'niemiec'],
#  [' ',
#   'biały',
#   'bocian',
#   'Słony',
#   'Karmel',
#   'likier',
#   'mleczny',
#   'mleczny',
#   'likier',
#   'modny',
#   'smak',
#   'słony',
#   'karmel',
#   'elegancki',
#   'połączyć',
#   'karmel',
#   'mleczny',
#   'biały',
#   'czekolada',
#   'nugat',
#   'wyczuwalny',
#   'zapach',
#   'słoność',
#   'przyjemny',
#   'smak',
#   'delikatny',
#   'słodki',
#   'biały',
#   'czekolada',
#   'orzech',
#   'finisz',
#   'harmonijny',
#   'połączyć',
#   'spory',
#   'porcja',
#   'słodycz',
#   'słoność',
#   'biały',
#   'czekolada',
#   'Wanillia',
#   'delikatny',
#   'słony',
#   'karmel',
#   'biały',
#   'czekolada',
#   'nugat',
#   'morski',
#   'sól',
#   'słodki',
#   'słony',
#   'Polska'],
#  ['biały',
#   'bocian',
#   'Advocat',
#   'likier',
#   'jajeczny',
#   'Aksamitny',
#   'delikatny',
#   'likier',
#   'jajeczny',
#   'dodatek',
#   'mleko',
#   'wyjątkowy',
#   'smak',
#   'zawdzięczać',
#   'połączyć',
#   'naturalny',
#   'składnik',
#   'sprowadzać',
#   'Madagaskar',
#   'wanilia',
#   'aromatyczny',
#   'brandy',
#   'doskonały',
#   'spirytus',
#   'wielkopolski',
#   'zboże',
#   'świeży',
#   'żółtko',
#   'jajo',
#   'kurzy',
#   'wanilia',
#   'jajo',
#   'kura',
#   'advokat',
#   'wanilia',
#   'łagodny',
#   'mleczny',
#   'Polska'],
#  ['James',
#   'cook',
#   'white',
#   'oversea',
#   'rum',
#   'biały',
#   'łagodny',
#   'smak',
#   'często',
#   'wykorzystywać',
#   'przygotowywać',
#   'drinek',
#   'pożądany',
#   'łagodny',
#   'smak',
#   'na przykład',
#   'Pina',
#   'Colada',
#   'mojito',
#   'Cuba',
#   'Libre',
#   '  ',
#   'Niemiec'],
#  [' ',
#   'Krupnik',
#   'Słony',
#   'Karmel',
#   'likier',
#   'mleczny',
#   'Wyprodukować',
#   '100',
#   'naturalny',
#   'składnik',
#   'Najlepiej',
#   'pić',
#   'sam',
#   'połączyć',
#   'ulubiony',
#   'whisky',
#   'likier',
#   'fantastyczny',
#   'aksamitny',
#   'konsystencja',
#   'piękny',
#   'bursztynowy',
#   'kolor',
#   'śmietanka',
#   'karmel',
#   'sól',
#   'karmel',
#   'sól',
#   'łagodny',
#   'słodki',
#   'słony',
#   'Polska'],
#  ['Havana',
#   'Club',
#   'Anejo',
#   'Especial',
#   'rum',
#   'złoty',
#   'mieszanka',
#   'stary',
#   'młody',
#   'rum',
#   'zostać',
#   'poddać',
#   'proces',
#   'starzenie',
#   '5',
#   'rok',
#   'Łączy',
#   'lekkość',
#   'biały',
#   'rum',
#   'aromat',
#   'rum',
#   'ciemny',
#   'Charakteryzuje',
#   'jasny',
#   'ciepły',
#   'przykuwać',
#   'uwaga',
#   'złoty',
#   'kolor',
#   'najlepiej',
#   'smakować',
#   'cola',
#   'limonka',
#   'lód',
#   'cynamon',
#   'kawa',
#   'wanilia',
#   'kakao',
#   'cukier',
#   'trzcinowy',
#   'trzcina',
#   'cukrowy',
#   'wanilia',
#   'miód',
#   'cynamon',
#   'kawa',
#   'tytoń',
#   'dług',
#   'korzenny',
#   'waniliowy',
#   'Kuba'],
#  ['sheridans',
#   'Coffee',
#   'Layered',
#   'Liqueur',
#   'likier',
#   'kawowy',
#   'Unikatowy',
#   'butelka',
#   'podzielić',
#   'część',
#   'jeden',
#   'zawrzeć',
#   'napój',
#   'kawowy',
#   'drugi',
#   'napój',
#   'mleczny',
#   'czekolada',
#   'likier',
#   'zawierać',
#   'doskonały',
#   'jakość',
#   'irlandzki',
#   'whisky',
#   'słodki',
#   'kawowy',
#   'mleczny',
#   'biały',
#   'czekolada',
#   'kawowy',
#   'mleczny',
#   'kawowy',
#   'Irlandia'],
#  ['Captain',
#   'Morgan',
#   'Original',
#   'Spiced',
#   'Gold',
#   'rum',
#   'złoty',
#   'Świetnie',
#   'komponować',
#   'cola',
#   'soek',
#   'jabłkowy',
#   'napój',
#   'imbirowy',
#   'mix',
#   'rum',
#   'prosto',
#   'Karaiby',
#   'drobiazgowo',
#   'kontrolować',
#   'proces',
#   'potrójny',
#   'destylacja',
#   'leżakować',
#   'dębowy',
#   'beczka',
#   'Bourbonie',
#   'Wyróżnia',
#   'unikalny',
#   'głębia',
#   'intensywność',
#   'smak',
#   'wanilia',
#   'cynamon',
#   'kwiat',
#   'wanilia',
#   'przyprawa',
#   'owoc',
#   'łagodny',
#   'Anglia'],
#  ['Captain',
#   'Morgan',
#   'White',
#   'Rum',
#   'rum',
#   'biały',
#   'idealnie',
#   'pasować',
#   'baza',
#   'drinek',
#   'lekki',
#   'rześki',
#   'rum',
#   'zrównoważony',
#   'kremowy',
#   'charakter',
#   'posiadać',
#   'lżejszy',
#   'bukiet',
#   'smakowy',
#   'wzgląd',
#   'biały',
#   'rum',
#   'głęboki',
#   'porównanie',
#   'rumowa',
#   'lekki',
#   'słodki',
#   'rześki',
#   'palić',
#   'cukier',
#   'orzech',
#   'wytrawny',
#   'Anglia'],
#  ['she',
#   'Słony',
#   'Karmel',
#   'likier',
#   'mleczny',
#   'połączenie',
#   'wysoki',
#   'jakość',
#   'składnik',
#   'wyjątkowy',
#   'receptura',
#   'kolekcja',
#   'SHE',
#   'idealny',
#   'propozycja',
#   'kobieta',
#   'poszukuć',
#   'nowy',
#   'doznanie',
#   'smakowy',
#   'czerpiących',
#   'radość',
#   'wspólny',
#   'chwila',
#   'spędzić',
#   'damski',
#   'grono',
#   'Uwagę',
#   'przykuwać',
#   'smukły',
#   'butelka',
#   'elegancki',
#   'matowy',
#   'czerń',
#   'wyrazisty',
#   'element',
#   'kolorystyczny',
#   'Świetnie',
#   'smakować',
#   'połączenie',
#   'rum',
#   'słodki',
#   'słony',
#   'karmel',
#   'mleczny',
#   'słony',
#   'słodki',
#   'słony',
#   'Polska'],
#  ['she',
#   'kawa',
#   'Pomarańczą',
#   'likier',
#   'kawowy',
#   'połączenie',
#   'wysoki',
#   'jakość',
#   'składnik',
#   'wyjątkowy',
#   'receptura',
#   'kolekcja',
#   'SHE',
#   'idealny',
#   'propozycja',
#   'kobieta',
#   'poszukuć',
#   'nowy',
#   'doznanie',
#   'smakowy',
#   'czerpiących',
#   'radość',
#   'wspólny',
#   'chwila',
#   'spędzić',
#   'damski',
#   'grono',
#   'Uwagę',
#   'przykuwać',
#   'smukły',
#   'butelka',
#   'elegancki',
#   'matowy',
#   'czerń',
#   'wyrazisty',
#   'element',
#   'kolorystyczny',
#   'Świetnie',
#   'smakować',
#   'połączyć',
#   'piwo',
#   'espresso',
#   'mleko',
#   'kawa',
#   'pomarańcz',
#   'słodki',
#   'łagodny',
#   'pomarańcza',
#   'kawa',
#   'łagodny',
#   'kawowy',
#   'Polska'],
#  ['gran',
#   'Imperio',
#   'Rhum',
#   'Superior',
#   '7',
#   'YO',
#   'rum',
#   'złoty',
#   'poddany',
#   'proces',
#   'starzenie',
#   'komponować',
#   'składnik',
#   'drinek',
#   'posiadać',
#   'lekki',
#   'akcent',
#   'owocowy',
#   'zawrzeć',
#   'smak',
#   'aromat',
#   'charakterystyczny',
#   'starzony',
#   'ruiem',
#   'alkoholowy',
#   'mango',
#   'ananas',
#   'przyprawa',
#   'korzenny',
#   'goryczkowy',
#   'ananas',
#   'cynamon',
#   'goździk',
#   'pomarańcz',
#   'alkoholowy',
#   'krótki',
#   'alkoholowy',
#   'pieprzny',
#   'Włochy'],
#  ['Captain',
#   'Morgan',
#   'Black',
#   'Spiced',
#   'rum',
#   'czarny',
#   'aromatyczny',
#   'alkohol',
#   'stworzyć',
#   'karaibski',
#   'rum',
#   'idealnie',
#   'smakować',
#   'schłodzony',
#   'shota',
#   'podwójnie',
#   'ciemny',
#   'rum',
#   'starzić',
#   'podwójnie',
#   'opalać',
#   'beczka',
#   'wymieszać',
#   'starannie',
#   'wyselekcjonowanymi',
#   'przypraw',
#   'orzech',
#   'wanilia',
#   'goździk',
#   'czekolada',
#   'mleczny',
#   'przyprawa',
#   'masło',
#   'czekolada',
#   'Anglia'],
#  ['Havana',
#   'Club',
#   'Anejo',
#   '3',
#   'anos',
#   'rum',
#   'biały',
#   'klarowny',
#   'jasny',
#   'rum',
#   'delikatny',
#   'zabarwienie',
#   'trzyletni',
#   'Havana',
#   'Club',
#   'biały',
#   'rum',
#   'okres',
#   'dojrzewać',
#   'filtrować',
#   'cel',
#   'usunąć',
#   'kolor',
#   'utrzymać',
#   'przeźroczystość',
#   'szczęście',
#   'tracić',
#   'swój',
#   'delikatny',
#   'charakter',
#   'słodki',
#   'nuta',
#   'owocowy',
#   'tytoniowy',
#   'waniliowy',
#   'Idealny',
#   'mojito',
#   'Daiquiri',
#   ' ',
#   'banan',
#   'gruszka',
#   'cynamon',
#   'pieprz',
#   'pieprz',
#   'lukrecja',
#   'gruszka',
#   'cytrus',
#   'toffi',
#   'średnio',
#   'dług',
#   'lekki',
#   'goryczka',
#   'Anglia'],
#  ['Captain',
#   'Morgan',
#   'Dark',
#   'Rum',
#   'rum',
#   'czarny',
#   'Blendowany',
#   'rum',
#   'styl',
#   'angielski',
#   'Gładki',
#   'bogaty',
#   'dębowy',
#   'smak',
#   'rum',
#   'Captain',
#   'Morgan',
#   'Dark',
#   'sprawiać',
#   '\u200b\u200bjest',
#   'idealny',
#   'trunek',
#   'pić',
#   'stan',
#   'czysty',
#   'zacumowanym',
#   'skała',
#   'uzyskać',
#   'prawdziwy',
#   'poncz',
#   'rumowy',
#   'móc',
#   'zmieszać',
#   'ulubiony',
#   'koktajli',
#   'ciemny',
#   'rum',
#   'Kapitan',
#   'karmel',
#   'melasa',
#   'czekolada',
#   'karmel',
#   'czekolada',
#   'przyprawowy',
#   'słodki',
#   'dymny',
#   'karmel',
#   'czekolada',
#   'Anglia'],
#  ['Bacardi',
#   'Carta',
#   'Negra',
#   'rum',
#   'czarny',
#   'Świetny',
#   'składnik',
#   'drinek',
#   'smakować',
#   'shota',
#   'doskonale',
#   'smakować',
#   'pomarańcz',
#   'cynamon',
#   'Charakteryzuje',
#   'słodki',
#   'początk',
#   'tropikalny',
#   'owoc',
#   'połączyć',
#   'delikatny',
#   'nuta',
#   'maślany',
#   'nuta',
#   'karmel',
#   'wanilia',
#   'kończyć',
#   'wędzony',
#   'lukrecja',
#   'melasa',
#   ' ',
#   'wanilia',
#   'owoc',
#   'czekolada',
#   'egzotyczny',
#   'owoc',
#   'palyć',
#   'migdał',
#   'wanilia',
#   'karmel',
#   'krótki',
#   'słodki',
#   'Puerto',
#   'Rico'],
#  ['Bacardi',
#   'Spiced',
#   'rum',
#   'złoty',
#   'Wpisywać',
#   'modny',
#   'trend',
#   'rum',
#   'aromatyzowany',
#   'zwać',
#   'Spiced',
#   'destylat',
#   'dojrzewać',
#   'beczka',
#   'amerykański',
#   'bourbon',
#   'okres',
#   '1',
#   '2',
#   'rok',
#   'słodky',
#   'pikantny',
#   'lekko',
#   'dymny',
#   'cynamon',
#   'owoc',
#   'karmel',
#   'wanilia',
#   'słodki',
#   'przyprawa',
#   'karmel',
#   'suszić',
#   'owoc',
#   'słodki',
#   'średnio',
#   'dług',
#   'przyprawa',
#   'korzenny',
#   'Puerto',
#   'Rico'],
#  ['kraken',
#   'Black',
#   'Spiced',
#   'rum',
#   'czarny',
#   'oryginalny',
#   'rum',
#   'wyspa',
#   'Karaibski',
#   'destylować',
#   'tradycyjny',
#   'alembik',
#   'następnie',
#   'dojrzewać',
#   'dębowy',
#   'beczka',
#   'okres',
#   '12',
#   '24',
#   'miesiąc',
#   'specjalny',
#   'kompozycja',
#   'zioło',
#   'dodawać',
#   'proces',
#   'produkcja',
#   'tworzyć',
#   'niepowtarzalny',
#   'smak',
#   'zachwycać',
#   'swój',
#   'gładkość',
#   'złożony',
#   'charakter',
#   'dominować',
#   'akcent',
#   'mocny',
#   'espresso',
#   'karmel',
#   'imbir',
#   'goździk',
#   ' ',
#   'wanilia',
#   'czekolada',
#   'cynamon',
#   'wanilia',
#   'cynamon',
#   'czekolada',
#   'cukier',
#   'kawa',
#   'dług',
#   'wanilia',
#   'imbir'],
#  ['Malibu',
#   'Original',
#   'likier',
#   'biały',
#   'Malibu',
#   'swietnie',
#   'nadawać',
#   'różny',
#   'drinek',
#   'Świeży',
#   'łagodny',
#   'smak',
#   'zamknięty',
#   'butelka',
#   'Najlepiej',
#   'sprzedający',
#   'świat',
#   'rum',
#   'karaibski',
#   'smak',
#   'kokosowy',
#   'łączyć',
#   'mleko',
#   'początkowo',
#   'służyć',
#   'barman',
#   'tworzyć',
#   'Pina',
#   'Colada',
#   'słodki',
#   'orzeźwiający',
#   'kokos',
#   'owoc',
#   'egzotyczny',
#   'kokosowy',
#   'cukier',
#   'trzcinowy',
#   'korzeń',
#   'słodki',
#   'łagodny',
#   'Hiszpania'],
#  ['Crema',
#   'typ',
#   'Latte',
#   'Macchiato',
#   'likier',
#   'mleczny',
#   'Idealny',
#   'dodatek',
#   'kawa',
#   'lody',
#   'deser',
#   'pasować',
#   'mleko',
#   'lód',
#   'kawowy',
#   'mleczny',
#   'słodki',
#   'śmietankowy',
#   'kawowy',
#   'krótki',
#   'kawowy',
#   'Słowacja'],
#  ['Silvaner',
#   'Trocken',
#   'wino',
#   'wytrawny',
#   'Elegancki',
#   'wytrawny',
#   'wino',
#   'pochodzić',
#   'Niemcy',
#   'idealny',
#   'czerwony',
#   'mięs',
#   ' ',
#   'jabłko',
#   'mirabelka',
#   'cytrus',
#   'Niemiec'],
#  ['Cabernet',
#   'Sauvignon',
#   'wino',
#   'wytrawny',
#   'Czerwone',
#   'niezbyt',
#   'mocny',
#   'wino',
#   'Wyczuwalne',
#   'nuta',
#   'truskawka',
#   'dąb',
#   ' ',
#   'truskawka',
#   'wanilia',
#   'dąb',
#   'Włochy'],
#  ['Chardonnay',
#   'Viognie',
#   'Reserva',
#   'Privad',
#   'wino',
#   'wytrawny',
#   'orzeźwiający',
#   'wytrawny',
#   'wino',
#   'pochodzić',
#   'Chile',
#   ' ',
#   'brzoskwinia',
#   'melon',
#   'cytrus',
#   'chile'],
#  ['Chevalier',
#   'de',
#   'Fauvert',
#   'comté',
#   'Tolosan',
#   'wino',
#   'półsłodki',
#   'Biały',
#   'owocowy',
#   'wino',
#   'wyprodukować',
#   'Francja',
#   'orzeźwiający',
#   'delikatny',
#   'słodyczą',
#   'sprawiać',
#   'idealnie',
#   'pasować',
#   'deser',
#   ' ',
#   'brzoskwinia',
#   'mandarynka',
#   'mirabelka',
#   'Francja'],
#  ['NEGROAMARO',
#   'SALENTO',
#   'wino',
#   'wytrawny',
#   'wino',
#   'rubinowy',
#   'barwa',
#   'wytrawny',
#   'cierpki',
#   'trunek',
#   'aromat',
#   'suszoć',
#   'owoc',
#   'kakao',
#   ' ',
#   'suszyć',
#   'owoc',
#   'czarny',
#   'porzeczka',
#   'wołowina',
#   'Włochy'],
#  ['Carlo',
#   'Rossi',
#   'Refresh',
#   'Tropical',
#   'Moscato',
#   'wino',
#   'słodki',
#   'Słodki',
#   'wino',
#   'pełny',
#   'słodycz',
#   'orzeźwiający',
#   'nuta',
#   ' ',
#   'mango',
#   'ananas',
#   'marakuja',
#   'USA'],
#  ['Carlo',
#   'Rossi',
#   'Pink',
#   'Moscato',
#   'wino',
#   'słodki',
#   'Słodki',
#   'lekki',
#   'orzeźwiający',
#   'wino',
#   'nut',
#   'kwiat',
#   'soczysty',
#   'owoc',
#   ' ',
#   'mandarynka',
#   'brzoskwinia',
#   'kwiat',
#   'USA'],
#  ['Carlo',
#   'Rossi',
#   'Sweet',
#   'Red',
#   'wino',
#   'słodki',
#   'Słodki',
#   'czerwony',
#   'wino',
#   'aromat',
#   'świeży',
#   'owoc',
#   'wanilia',
#   'Cechuje',
#   'bogaty',
#   'zbalansować',
#   'smakie',
#   ' ',
#   'wanilia',
#   'USA'],
#  ['Merlot', 'Cimarosa', 'wino', 'wytrawny', '   ', 'Chile'],
#  ['Chenin',
#   'Blanc',
#   'wino',
#   'wytrawny',
#   '  ',
#   'melon',
#   'jabłko',
#   'cytrus',
#   'Południowy',
#   'Afryka'],
#  ['Canari',
#   'Salted',
#   'Caramel',
#   'likier',
#   'mleczny',
#   'doskonały',
#   'kremowy',
#   'likier',
#   'wyśmienity',
#   'smak',
#   'karmel',
#   'wzbogacoć',
#   'sola',
#   'świetnie',
#   'pasować',
#   'zarówno',
#   'deser',
#   'sprawdzić',
#   'pit',
#   'solo',
#   'słony',
#   'karmel',
#   'mleczny',
#   'delikatny',
#   'karmel',
#   'Polska'],
#  ['soplica',
#   'Śliwkowa',
#   'likier',
#   'owocowy',
#   'starannie',
#   'wyselekcjonować',
#   'owoc',
#   'profesjonalny',
#   'przetwórstwo',
#   'sprawiać',
#   'wysoki',
#   'jakość',
#   'trunek',
#   'Świetnie',
#   'smakować',
#   'shot',
#   'nadawać',
#   'drinek',
#   'owocowy',
#   'przykład',
#   'soek',
#   'pomarańcz',
#   'żurawina',
#   'śliwkowy',
#   'śliwkowy',
#   'łagodny',
#   'Polska'],
#  ['Lubuski',
#   'Gin',
#   'gin',
#   'destylować',
#   'Gin',
#   'Lubuski',
#   'wytwarzać',
#   'niezmienny',
#   'receptura',
#   '1987',
#   'Wyróżnia',
#   'wyrazisty',
#   'smakie',
#   'jałowiec',
#   'Świetnie',
#   'nadawać',
#   'drink',
#   'przykład',
#   'toniek',
#   'typ',
#   'gin',
#   'świadczyć',
#   'wysoki',
#   'jakość',
#   'jałowiec',
#   'jałowiec',
#   'majeranek',
#   'lawenda',
#   'kolendra',
#   'Polska'],
#  ['soplica',
#   'Orzech',
#   'Laskowy',
#   'likier',
#   'orzechowy',
#   'Aromatyczna',
#   'nuta',
#   'orzechów',
#   'laskowy',
#   'zapewniać',
#   'łagodny',
#   'kremowy',
#   'smak',
#   'pić',
#   'shot',
#   'świetnie',
#   'komponować',
#   'dodatek',
#   'gorący',
#   'czekolada',
#   'orzech',
#   'laskowy',
#   'słodki',
#   'rozgrzewać',
#   'orzech',
#   'laskowy',
#   'wanilia',
#   'toffi',
#   'Polska'],
#  ['soplica',
#   'Kawowy',
#   'likier',
#   'kawowy',
#   'głęboki',
#   'smak',
#   'wyjątkowo',
#   'aromatyczny',
#   'kawa',
#   'połączyć',
#   'przyjemny',
#   'nuta',
#   'słodycze',
#   'Świetnie',
#   'nadawać',
#   'solo',
#   'pasować',
#   'toniek',
#   'czekolada',
#   'kawa',
#   'kawowy',
#   'słodki',
#   'kawowy',
#   'łagodny',
#   'Polska'],
#  ['Dalkowski',
#   'ananasowy',
#   'likier',
#   'ananasowy',
#   'baza',
#   ' ',
#   'ananasowy',
#   'ananasowy',
#   'Polska'],
#  ['Adam',
#   'Mickiewicz',
#   'wódka',
#   'czysty',
#   'Wodka',
#   'Adam',
#   'Mickiewicz',
#   'symbol',
#   'tradycja',
#   'hołd',
#   'wielkiy',
#   'Polak',
#   'dedykować',
#   'wyjątkowy',
#   'produkt',
#   'wódka',
#   'Adam',
#   'Mickiewicz',
#   'zawieźć',
#   'degustator',
#   'żaden',
#   'wzgląd',
#   'stać',
#   'cały',
#   'proces',
#   'czuwać',
#   'osoba',
#   'producent',
#   'BZK',
#   'ALKO',
#   'tworzyć',
#   'podstawa',
#   'receptura',
#   'inspirować',
#   'XIX',
#   'wiek',
#   'Adam',
#   'Mickiewicz',
#   'wódka',
#   'zostawać',
#   'poddawać',
#   'wielostopniowy',
#   'filtracja',
#   'węgiel',
#   'co',
#   'wielokrotnie',
#   'destylować',
#   'wódka',
#   'powstać',
#   'alkohol',
#   'etylowy',
#   'wysoki',
#   'jakość',
#   'pochodzenie',
#   'kukurydziany',
#   'zboże',
#   'pozbawiyć',
#   'gluten',
#   'dzięki',
#   'odpowiedni',
#   'selekcja',
#   'surowiec',
#   'GMO',
#   'certyfikować',
#   'gospodarstwo',
#   'Drugim',
#   'rodzajem',
#   'alkohol',
#   'Adam',
#   'Mickiewicz',
#   'leżakować',
#   'wódka',
#   'premium',
#   'wyjątkowy',
#   'połączenie',
#   'aksamitnie',
#   'gładkiy',
#   'smak',
#   'zamkniętego',
#   'smukły',
#   'miedziać',
#   'czarny',
#   'butelka',
#   'swój',
#   'niezwykłość',
#   'zawdzięczać',
#   'minimum',
#   '7',
#   'tygodniowemu',
#   'leżakowaniu',
#   'metalowy',
#   'zbiornik',
#   'Okresowym',
#   'mieszanie',
#   'umożliwiać',
#   'kontakt',
#   'powietrz',
#   'harmonizacja',
#   'płyn',
#   'Używany',
#   'produkcja',
#   'wódka',
#   'wysoki',
#   'jakość',
#   'spirytus',
#   'siedmiokrotnie',
#   'destylować',
#   'produkt',
#   'doskonale',
#   'nadawać',
#   'prezent',
#   'wspólny',
#   'spotkanie',
#   'okraszć',
#   'dobry',
#   'alkohol',
#   'Zawartość',
#   'alkohol',
#   '40',
#   '  ',
#   'Polska'],
#  ['Barefoot',
#   'Pinot',
#   'Grigio',
#   'wino',
#   'półwytrawny',
#   'Barefoot',
#   'Pinot',
#   'Grigio',
#   'biały',
#   'półwytrawny',
#   'kalifornijski',
#   'wino',
#   'logo',
#   'marka',
#   'Barefoot',
#   'odzwierciedlać',
#   'filozofia',
#   'życiowy',
#   'założyciel',
#   'pełny',
#   'optymizm',
#   'ukierunkować',
#   'dobry',
#   'zabawa',
#   'realizować',
#   'swój',
#   'pasja',
#   'smak',
#   'wino',
#   'móc',
#   'wyczuć',
#   'nutka',
#   'cytryna',
#   'brzoskwinia',
#   'idealny',
#   'drobiu',
#   'owoc',
#   'morze',
#   'pikantny',
#   'sos',
#   ' ',
#   'cytryna',
#   'brzoskwinia',
#   'USA'],
#  ['Dictador',
#   '12YO',
#   'rum',
#   'złoty',
#   'Kolumbijski',
#   'rum',
#   'bogaty',
#   'zapach',
#   'łagodny',
#   'smak',
#   'opakować',
#   'elegancki',
#   'ciemny',
#   'matowy',
#   'butelka',
#   'przystępny',
#   'degustacja',
#   'doskonały',
#   'początkujący',
#   'smakosz',
#   'trunek',
#   'Karaiby',
#   'Karmel',
#   'kakao',
#   'miód',
#   'wanilia',
#   'miód',
#   'orzech',
#   'delikatny',
#   'wanilia',
#   'Kolumbia'],
#  ['absolut',
#   'Vodek',
#   'wódka',
#   'czysty',
#   'odważny',
#   'oryginalny',
#   'kreatywny',
#   'absolut',
#   'Vodek',
#   'zadebiutować',
#   'Nowy',
#   'Jork',
#   '1979',
#   'przezroczysta',
#   'butelka',
#   'pozbawić',
#   'etykieta',
#   'inspirować',
#   'wygląd',
#   'osiemnastowieczny',
#   'buteleczka',
#   'lek',
#   'wyróżniać',
#   'tło',
#   'wysoki',
#   'krzykliwy',
#   'produkt',
#   'konkurencja',
#   'koniec',
#   'mówić',
#   'nowy',
#   'Jork',
#   'rok',
#   '70',
#   'wyróżniać',
#   'zauważony',
#   'inspiracja',
#   'dzięki',
#   'współpraca',
#   'współpraca',
#   'absolut',
#   'artysta',
#   'uczony',
#   'bezprecedensowy',
#   'wydarzenie',
#   'pierwszy',
#   'rozpoczęć być',
#   'współpraca',
#   'Andym',
#   'Warhol',
#   '1985',
#   'rok',
#   'sukces',
#   'projekt',
#   'Absolut',
#   'Warhol',
#   'zapoczątkować',
#   'rodzaj',
#   'sztafeta',
#   'pałeczka',
#   'marka',
#   'Absolut',
#   'czas',
#   'przekazywać',
#   '550',
#   'artysta',
#   'Spritmuseum',
#   'Sztokholm',
#   'znajdować',
#   'obecnie',
#   '850',
#   'dzieło',
#   'sztuka',
#   'warto',
#   'przyjechać',
#   'zobaczyć',
#   'reklama',
#   'zasada',
#   'przeciwieństwo',
#   'marka',
#   'organizować',
#   'głośny',
#   'wymyślny',
#   'kampania',
#   'postanowić być',
#   'stworzyć',
#   'subtelny',
#   'powściągliwy',
#   'zgodnie',
#   'nasz',
#   'skandynawski',
#   'korzenia',
#   'połączyć',
#   'giera',
#   'słowny',
#   'postać',
#   'wizualny',
#   'werbalny',
#   'efektowny',
#   'obraz',
#   'słynny',
#   'sylwetka',
#   'butelka',
#   'umieszczć',
#   'reklama',
#   'duma',
#   'móc',
#   'powiedzieć',
#   'najdłużej',
#   'trwający',
#   'kampania',
#   'marketingowy',
#   'historia',
#   'reklama',
#   'ewolucja',
#   'rewolucja',
#   'absolut',
#   'Vodek',
#   'nieustannie',
#   'wyróżniać',
#   'unikatowy',
#   'charakter',
#   'zarówno',
#   'kwestia',
#   'wzornictwo',
#   'smak',
#   'interesować',
#   'kreatywność',
#   'współpraca',
#   'sztuka',
#   'nadal',
#   'być',
#   'kluczowy',
#   'składnik',
#   'idealny',
#   'drinek',
#   'każdy',
#   'okazja',
#   'wódka',
#   'marka',
#   'Absolut',
#   'produkować',
#   'południowy',
#   'Szwecja',
#   'wspaniały',
#   'produkt',
#   'smakować',
#   'dokładnie',
#   'samo',
#   'dawno',
#   'kwestia',
#   'zmienić',
#   '  ',
#   'Szwecja'],
#  ['SAUVIGNON',
#   'BLANC',
#   'SEMILLON',
#   'CIMAROSA',
#   'wino',
#   'wytrawny',
#   'Australijski',
#   'kompozycja',
#   'odmiana',
#   'Sauvignon',
#   'Blanc',
#   'Sémillon',
#   'trunek',
#   'posiadać',
#   'przyjemny',
#   'bukiet',
#   'charakterystyka',
#   'owocowy',
#   'wyróżniać',
#   'akcent',
#   'owoc',
#   'mango',
#   'miechunek',
#   'kandyzowany',
#   'ananas',
#   'brzoskwinia',
#   'kwiat',
#   'jaśmin',
#   'wino',
#   'polecać',
#   'potrawa',
#   'drobiu',
#   'smażoć',
#   'ryba',
#   'warzywny',
#   'tarta',
#   'zapiekanka',
#   ' ',
#   'cytrus',
#   'Australia'],
#  ['Malibu',
#   'Passion',
#   'Fruit',
#   'rum',
#   'biały',
#   'Malibu',
#   'swietnie',
#   'nadawać',
#   'różny',
#   'drinek',
#   'Świeży',
#   'łagodny',
#   'smak',
#   'zamknięty',
#   'butelka',
#   'Najlepiej',
#   'sprzedający',
#   'świat',
#   'rum',
#   'karaibski',
#   'smak',
#   'egzotyczny',
#   'marakui',
#   'słodki',
#   'orzeźwiający',
#   'owoc',
#   'egzotyczny',
#   'marakuja',
#   'cukier',
#   'trzcinowy',
#   'marakuja',
#   'łagodny',
#   'słodki',
#   'Hiszpania'],
#  ['Jameson',
#   'whisky',
#   'blended',
#   'Jameson',
#   'popularny',
#   'irlandzki',
#   'whisky',
#   'typ',
#   'blended',
#   'przedstawiać',
#   'świetny',
#   'połączenie',
#   'nuta',
#   'owocowy',
#   'orzechowy',
#   'akcent',
#   'drewno',
#   'zostać',
#   'wyprodukować',
#   'połączenie',
#   'whiskey',
#   'zbożowy',
#   'whiskey',
#   'typ',
#   'pot',
#   'still',
#   'destylowanej',
#   'alembik',
#   'Destylowana',
#   'trzykrotnie',
#   'następnie',
#   'dojrzewać',
#   'mało',
#   '4',
#   'rok',
#   'dębowy',
#   'beczka',
#   'nuta',
#   'korzenny',
#   'orzech',
#   'wanilia',
#   'słodki',
#   'sherry',
#   'łagodny',
#   'nuta',
#   'kwiatowy',
#   'owoc',
#   'nuta',
#   'korzenny',
#   'drewno',
#   'gładki',
#   'słodki',
#   'pikantny',
#   'Irlandia'],
#  ['Jameson',
#   'Caskmates',
#   'Stout',
#   'Edition',
#   'whisky',
#   'blended',
#   'efekt',
#   'współpraca',
#   'destylarni',
#   'Jameson',
#   'właściciel',
#   'browar',
#   'Franciscan',
#   'Well',
#   'hrabstwo',
#   'Cork',
#   'zostać',
#   'poddać',
#   'proces',
#   'dodatkowy',
#   'dojrzewać',
#   'beck',
#   'dojrzewać',
#   'piwo',
#   'stout',
#   'Łagodność',
#   'uzyskiwać',
#   'dzięki',
#   'potrójny',
#   'destylacja',
#   'Charakteryzuje',
#   'wyczuwalny',
#   'nut',
#   'kakao',
#   'kawa',
#   'karmel',
#   'niezaprzeczalny',
#   'wpływ',
#   'piwo',
#   'stout',
#   'mleczny',
#   'czekolada',
#   'chmiel',
#   'kakao',
#   'marcepanć',
#   'nuta',
#   'owocowy',
#   'jabłko',
#   'gruszka',
#   'nuta',
#   'korzenny',
#   'orzech',
#   'skórka',
#   'limonka',
#   'dług',
#   'słodki',
#   'mleczny',
#   'czekolada',
#   'karmel',
#   'Irlandia'],
#  ['Chenin',
#   'Blanc',
#   'South',
#   'Afrika',
#   'wino',
#   'wytrawny',
#   '  ',
#   'cytrus',
#   'jabłko',
#   'gruszka',
#   'RPA'],
#  ['Jack',
#   "Daniel's",
#   'Old',
#   '7',
#   'whisky',
#   'Tennessee',
#   'whiskey',
#   'miłośnik',
#   'whisky',
#   'zetknąć',
#   'kiedyś',
#   'trunkie',
#   'najpopularniejsza',
#   'amerykański',
#   'whiskey',
#   'produkować',
#   '1866',
#   'Jasper',
#   'Jack',
#   'Daniel',
#   'zaufać',
#   'swój',
#   'intuicja',
#   'postawić',
#   'stworzyć',
#   'wysoki',
#   'jakość',
#   'trunek',
#   'Łagodzona',
#   'kropla',
#   'kropla',
#   '3',
#   'metr',
#   'cukrowy',
#   'węgiel',
#   'drzewny',
#   'klonowy',
#   'następnie',
#   'dojrzewać',
#   'ręcznie',
#   'robioć',
#   'beczk',
#   'własny',
#   'produkcja',
#   'słodki',
#   'wanilia',
#   'pieprz',
#   'węgiel',
#   'drzewny',
#   'karmel',
#   'wanilia',
#   'kukurydza',
#   'orzech',
#   'drewno',
#   'drewno',
#   'wanilia',
#   'karmel',
#   'pieprz',
#   'USA'],
#  ['costa',
#   'Azul',
#   'shiraz',
#   'wino',
#   'wytrawny',
#   'wytrawny',
#   'wino',
#   'purpurowy',
#   'barwa',
#   'pochodzić',
#   'Hiszpani',
#   ' ',
#   'czarny',
#   'porzeczka',
#   'czerwony',
#   'porzeczka',
#   'śliwka',
#   'jeżyna',
#   'Hiszpania'],
#  ['Jack',
#   "Daniel's",
#   'Gentleman',
#   'Jack',
#   'whisky',
#   'Tennessee',
#   'whiskey',
#   'zainspirować',
#   'oryginalny',
#   'gorzelnik',
#   'dżentelmen',
#   'założyciel',
#   'Gentleman',
#   'Jack',
#   'poddawać',
#   'drugi',
#   'zmiękczenie',
#   'węgiel',
#   'uzyskać',
#   'wyjątkowy',
#   'gładkość',
#   'zrównoważony',
#   'smak',
#   'idealny',
#   'celebrować',
#   'niezwykły',
#   'okazja',
#   'życie',
#   'chwila',
#   'droga',
#   'pierwszy',
#   'filtracja',
#   'odbywać',
#   'dojrzewanie',
#   'destylat',
#   'ręcznie',
#   'robioć',
#   'dębowy',
#   'beczek',
#   'drugi',
#   'tuż',
#   'rozlać',
#   'gotowy',
#   'whiskey',
#   'piękny',
#   'kwadratowy',
#   'butelka',
#   ' ',
#   'wanilia',
#   'karmel',
#   'pieprz',
#   'pieczyć',
#   'banan',
#   'miód',
#   'cynamon',
#   'mleczny',
#   'czekolada',
#   'kukurydza',
#   'węgiel',
#   'drzewny',
#   'karmel',
#   'kukurydza',
#   'miód',
#   'węgiel',
#   'drzewny',
#   'USA'],
#  ['Serpasso',
#   'Duca',
#   'di',
#   'Sasseta',
#   'wino',
#   'półwytrawny',
#   'cierpki',
#   'półwytrawny',
#   'wino',
#   'Włochy',
#   'idalnie',
#   'nadawać',
#   'mięs',
#   ' ',
#   'wiśnia',
#   'czereśeń',
#   'jeżyna',
#   'Włochy'],
#  ['Jack',
#   "Daniel's",
#   'Single',
#   'Barrel',
#   'Select',
#   'whisky',
#   'Tennessee',
#   'whiskey',
#   'luksusowy',
#   'whiskey',
#   'dojrzewać',
#   'warunki',
#   'wielki',
#   'zmiana',
#   'temperatura',
#   'wpływać',
#   'niesamowity',
#   'kolor',
#   'głębia',
#   'smak',
#   'podobnie',
#   'podstawowy',
#   'Jack',
#   "Daniel's",
#   'zakończyć',
#   'staranny',
#   'destylacja',
#   'poddawać',
#   'proces',
#   'filtracja',
#   'kolumna',
#   'węgiel',
#   'drzewny',
#   'cały',
#   'okres',
#   'dojrzewać',
#   'whiskey',
#   ' ',
#   'wysoko',
#   'wymienić',
#   'warunki',
#   'odparowować',
#   '30',
#   'drogocenny',
#   'trunek',
#   'angel',
#   'share',
#   'udział',
#   'anioł',
#   'proces',
#   'tworzyć',
#   'pochodzić',
#   'pojedynczy',
#   'ręcznie',
#   'wybierać',
#   'beczka',
#   'stanowić',
#   'przejaw',
#   'olbrzymi',
#   'doświadczenie',
#   'wiedza',
#   'master',
#   'Blender',
#   'destylarnia',
#   'Jack',
#   "Daniel's",
#   'podkreślić',
#   'indywidualny',
#   'charakter',
#   'whisky',
#   'każdy',
#   'butelka',
#   'oznaczić',
#   'numer',
#   'beczka',
#   'pochodzić',
#   'data',
#   'rozlać',
#   'wanilia',
#   'drewno',
#   'orzech',
#   'Marcepan',
#   'karmel',
#   'pieprz',
#   'gruszka',
#   'mocny',
#   'drewno',
#   'wanilia',
#   'USA'],
#  ['Dornfelder',
#   'Halbtrocken',
#   'wino',
#   'półwytrawny',
#   'niemiecki',
#   'czerwony',
#   'wino',
#   'półwytrawny',
#   'łagodnie',
#   'kwaskowy',
#   ' ',
#   'truskawka',
#   'czereśeń',
#   'Wanilia',
#   'Niemiec'],
#  ['Jim',
#   'Beam',
#   'whisky',
#   'bourbon',
#   'Jim',
#   'Beam',
#   'Kentucky',
#   'Straight',
#   'Bourbon',
#   'Whiskey',
#   'sławny',
#   'najpopularniejszy',
#   'bourbon',
#   'świat',
#   'chyba',
#   'nikt',
#   'znać',
#   'whiskey',
#   'podstawowy',
#   'czteroletni',
#   'wypust',
#   'destylarnia',
#   'Jim',
#   'Beam',
#   'stanowić',
#   'trzon',
#   'portfolio',
#   'marka',
#   'Elegancki',
#   'łagodny',
#   'wyrafinowany',
#   '4',
#   'rok',
#   'bourbon',
#   'dojrzewać',
#   'beczka',
#   'amerykański',
#   'biały',
#   'dąb',
#   'nadawać',
#   'wyjątkowy',
#   'jakość',
#   'każdy',
#   'kropla',
#   'wytwarzać',
#   'zgodnie',
#   'receptura',
#   'stworzoć',
#   'pradziadk',
#   'rodzina',
#   'Beam',
#   'każdy',
#   'kropla',
#   'warty',
#   'wysiłek',
#   'słodki',
#   'opalony',
#   'drewno',
#   'owoc',
#   'wanilia',
#   'kukurydza',
#   'kukurydza',
#   'cynamon',
#   'drewno',
#   'karmel',
#   'lukrecja',
#   'wanilia',
#   'miód',
#   'orzech',
#   'pieprz',
#   'USA'],
#  ['Jim',
#   'Beam',
#   "Devil's",
#   'Cut',
#   'whisky',
#   'bourbon',
#   'wydobywany',
#   'ekstrakt',
#   'dębowy',
#   'beczka',
#   'mieszać',
#   'ekstra',
#   'dojrzały',
#   'Kentucky',
#   'whiskey',
#   'powstawać',
#   'bourbon',
#   'prawdziwy',
#   'klasa',
#   'premium',
#   'proces',
#   'leżakować',
#   'pewien',
#   'ilość',
#   'destylat',
#   'zostawać',
#   'uwięzić',
#   'dębowy',
#   'drewno',
#   'beczka',
#   'Devil',
#   's',
#   'Cut',
#   'powstawać',
#   'dzięki',
#   'odzyskiwać',
#   'destylat',
#   'drewno',
#   'wymieszać',
#   'dojrzały',
#   'wcześnie',
#   'whisky',
#   ' ',
#   'słodki',
#   'orzech',
#   'cynamon',
#   'karme',
#   'drewno',
#   'drewno',
#   'kukurydza',
#   'wanilia',
#   'suszić',
#   'owoc',
#   'karmel',
#   'drewno',
#   'karmel',
#   'cynamon',
#   'pieprz',
#   'imbir',
#   'USA'],
#  ['Jim',
#   'Beam',
#   'Double',
#   'Oak',
#   'whisky',
#   'bourbon',
#   'Jim',
#   'Beam',
#   'Double',
#   'Oak',
#   'synonim',
#   'nowy',
#   'jakość',
#   'dojrzewać',
#   'bourbć',
#   'zaczynać',
#   'klasyczny',
#   'Jim',
#   'Beam',
#   'leżakować',
#   '4',
#   'rok',
#   'następnie',
#   'alkohol',
#   'przelewać',
#   'świeżo',
#   'palyć',
#   'beczka',
#   'dojrzewać',
#   'kolejny',
#   'rok',
#   'drugi',
#   'beczkowanie',
#   'pozwalać',
#   'wytworzeć',
#   'głębszej',
#   'lekko',
#   'korzenny',
#   'dębowy',
#   'nuta',
#   'aromat',
#   'bogaty',
#   'karmel',
#   'słodki',
#   'dym',
#   'karmel',
#   'drewno',
#   'czekolada',
#   'wanilia',
#   'karmel',
#   'toffi',
#   'drewno',
#   'migdał',
#   'czekolada',
#   'drewno',
#   'pieprz',
#   'wanilia',
#   'USA'],
#  ['Johnnie',
#   'Walker',
#   'Black',
#   'Label',
#   'whisky',
#   'blended',
#   'mistrzowsky',
#   'mieszanka',
#   'whisky',
#   'single',
#   'malt',
#   'zbożowy',
#   'cały',
#   'Szkocja',
#   'leżakować',
#   'mało',
#   '12',
#   'rok',
#   'Rezultatem',
#   'ponadczasowy',
#   'klasyk',
#   'głębia',
#   'równowaga',
#   'smak',
#   'Pij',
#   'lod',
#   'czysty',
#   'postać',
#   'Highballu',
#   'toffi',
#   'słodki',
#   'owoc',
#   'drewno',
#   'owoc',
#   'wanilia',
#   'pieprz',
#   'dym',
#   'karmel',
#   'czekolada',
#   'Szkocja'],
#  ['Johnnie',
#   'Walker',
#   'Red',
#   'Label',
#   'whisky',
#   'blended',
#   'koneser',
#   'budzić',
#   'kontrowersja',
#   'wzgląd',
#   'popularność',
#   'przypisywać',
#   'cecha',
#   "mainstrem'owego",
#   'trunek',
#   'Flagowa',
#   'marka',
#   'producent',
#   'Diageo',
#   'Stworzona',
#   'mieszać',
#   'zarówno',
#   'ekscytujący',
#   'koktajl',
#   'ulubiony',
#   'człowiek',
#   'Łączy',
#   'whisky',
#   'specjalnie',
#   'wybrać',
#   'wzgląd',
#   'odważny',
#   'żywy',
#   'smak',
#   'dodać',
#   'ognisty',
#   'kopa',
#   'każdy',
#   'mieszanka',
#   'cynamon',
#   'pieprz',
#   'karmel',
#   'cytrus',
#   'owoc',
#   'karmel',
#   'dym',
#   'toffi',
#   'Szkocja'],
#  ['Johnnie',
#   'Walker',
#   'Gold',
#   'Label',
#   'Reserve',
#   'whisky',
#   'blended',
#   'wielokrotnie',
#   'nagradzać',
#   'szkocki',
#   'wytwarzać',
#   'whisky',
#   'wybrać',
#   'wzgląd',
#   'słodki',
#   'miodowy',
#   'właściwość',
#   'Wybieramy',
#   'bardzo',
#   'żywy',
#   'uzyskać',
#   'wyrazisty',
#   'smak',
#   'każdy',
#   'kęs',
#   'model',
#   'nazywać',
#   'szampan',
#   'whisky',
#   'główny',
#   'składnik',
#   'Clynelish',
#   'single',
#   'malt',
#   'produkcja',
#   'stosować',
#   'woda',
#   'źródło',
#   'wypływać',
#   'wzgórze',
#   'Kildonan',
#   'Hills',
#   '1868',
#   'rok',
#   'odkryć',
#   'pokład',
#   'złoto',
#   'Johnnie',
#   'Walker',
#   'Gold',
#   'Label',
#   'Reserve',
#   'dedykować',
#   'celebrować',
#   'wyjątkowy',
#   'złoty',
#   'chwila',
#   'życie',
#   'owoc',
#   'wanilia',
#   'morela',
#   'cynamon',
#   'miód',
#   'drewno',
#   'karmel',
#   'pomarańczy',
#   'słodki',
#   'dym',
#   'toffi',
#   'Szkocja'],
#  ['Johnnie',
#   'Walker',
#   'Blue',
#   'Label',
#   'whisky',
#   'blended',
#   'Johnnie',
#   'Walker',
#   'Blue',
#   'Label',
#   'pochodzić',
#   'ręcznie',
#   'selekcjonować',
#   'rzadki',
#   'szkocki',
#   'whiskya',
#   'niezwykły',
#   'głębia',
#   'smak',
#   '10',
#   '000',
#   'beczka',
#   'przechodzić',
#   'selekcja',
#   'Najlepiej',
#   'podawać',
#   'czysty',
#   'postać',
#   'wraz',
#   'lodowaty',
#   'woda',
#   'wzmocnić',
#   'mocny',
#   'charakter',
#   'karmel',
#   'czekolada',
#   'orzech',
#   'wanilia',
#   'miód',
#   'rodzynka',
#   'dym',
#   'drewno',
#   'owoc',
#   'Szkocja'],
#  ['Johnnie',
#   'Walker',
#   'Green',
#   'Label',
#   'whisky',
#   'blended',
#   'jedyny',
#   'szkocki',
#   'marka',
#   'Johnnie',
#   'Walker',
#   'mieszać',
#   'całość',
#   'single',
#   'malt',
#   'Johnnie',
#   'Walker',
#   'Green',
#   'Label',
#   'ukryć',
#   'klejnot',
#   'żywy',
#   'sekreta',
#   'ujawnić',
#   'dzięki',
#   'słod',
#   'cztery',
#   'zakątek',
#   'Szkocja',
#   'dojrzewać',
#   'mało',
#   '15',
#   'rok',
#   'oddawać',
#   'idealny',
#   'równowaga',
#   'wyrazisty',
#   'smak',
#   'każdy',
#   'krajobraz',
#   'whisky',
#   'zgoda',
#   'natura',
#   'dym',
#   'nuta',
#   'korzenny',
#   'słodki',
#   'trawa',
#   'kwiat',
#   'owoc',
#   'cytrus',
#   'drewno',
#   'czekolada',
#   'owoc',
#   'Szkocja'],
#  ['Viura',
#   'Airen',
#   'Valdepenas',
#   'wino',
#   'wytrawny',
#   'Łączące',
#   'odmiana',
#   'hiszpański',
#   'wino',
#   'wytrawny',
#   'kwaskowy',
#   'pasować',
#   'owoc',
#   'morze',
#   'ryba',
#   ' ',
#   'owoc',
#   'tropikalny',
#   'jogurt',
#   'ciasto',
#   'drożdzowy',
#   'Hiszpania'],
#  ['portal',
#   'Minho',
#   'Branco',
#   'wino',
#   'półwytrawny',
#   'wieloszczepowy',
#   'portugalski',
#   'biały',
#   'wino',
#   'półwytrany',
#   'niesamowicie',
#   'ożeźwiające',
#   'znakomity',
#   'równowaga',
#   'smak',
#   ' ',
#   'owoc',
#   'tropikalny',
#   'cytryna',
#   'jabłko',
#   'Portugalia'],
#  ['portal',
#   'Minho',
#   'Loureiro',
#   'wino',
#   'półwytrawny',
#   'Ożeźwiające',
#   'biały',
#   'wino',
#   'pochodzić',
#   'Portugalia',
#   'rejon',
#   'mihno',
#   ' ',
#   'cytrus',
#   'jabłko',
#   'Portugalia'],
#  ['Chevalier',
#   'de',
#   'Fauvert',
#   'Merlot',
#   'wino',
#   'wytrawny',
#   'francuski',
#   'wino',
#   'zaskakywać',
#   'ciekawy',
#   'aromat',
#   'śliwka',
#   'malin',
#   'idealnie',
#   'pasować',
#   'obiad',
#   'zawierać',
#   'kaczka',
#   ' ',
#   'śliwka',
#   'czarny',
#   'porzeczka',
#   'wanilia',
#   'malina',
#   'Francja'],
#  ['Vineris',
#   'Bordeaux',
#   'wino',
#   'wytrawny',
#   'wino',
#   'Bordeaux',
#   'wytrawny',
#   'umiarkowanie',
#   'cierpki',
#   'doskonały',
#   'kompan',
#   'dziczyzna',
#   'stół',
#   ' ',
#   'czarny',
#   'porzeczka',
#   'śliwka',
#   'czekolada',
#   'Francja'],
#  ["Ballantine's",
#   '12yo',
#   'whisky',
#   'blended',
#   'Wyrafinowana',
#   'mieszanka',
#   'whiskya',
#   'wyselekcjowanych',
#   'szczytowy',
#   'moment',
#   'dojrzewać',
#   'Połączona',
#   'trunek',
#   'być',
#   'efekt',
#   'pasja',
#   'rzemiosło',
#   'whisky',
#   'miodowy',
#   'słodycza',
#   'doskonale',
#   'zrównoważony',
#   'nuta',
#   'dąb',
#   'wanilia',
#   'whisky',
#   'cierpliwy',
#   'doczekać',
#   'delektować',
#   'Ballantine',
#   's',
#   '12',
#   'zostać',
#   'stworzić',
#   'pasja',
#   'whisky',
#   'pasjonować',
#   'whisky',
#   'miód',
#   'nuta',
#   'kwiatowy',
#   'miód',
#   'drewno',
#   'wanilia',
#   'słodki',
#   'orzech',
#   'wanilia',
#   'miód',
#   'Szkocja'],
#  ["Ballantine's",
#   'Finest',
#   'whisky',
#   'blended',
#   "Ballantine's",
#   'Finest',
#   'whisky',
#   'typ',
#   'Blended',
#   'złożony',
#   'elegancki',
#   'smak',
#   'leżakuć',
#   'minimum',
#   '3',
#   'rok',
#   'przypadek',
#   'znacznie',
#   'długo',
#   'charakterystyczny',
#   'jasnozłoty',
#   'barwa',
#   'niezapomniany',
#   'smak',
#   'efekt',
#   'połączyć',
#   'różny',
#   'whiskya',
#   'słodowy',
#   'zbożowy',
#   'smak',
#   'dwa',
#   'główny',
#   'destylat',
#   'whisky',
#   'słodowy',
#   'Miltonduff',
#   'Glenburgie',
#   'sprawiać',
#   "Ballantine's",
#   'Finest',
#   'pobrzmiewać',
#   'nuta',
#   'czekolada',
#   'jabłko',
#   'wanilia',
#   'mleczny',
#   'czekolada',
#   'jabłko',
#   'wanilia',
#   'miód',
#   'nuta',
#   'korzenny',
#   'toffi',
#   'nuta',
#   'kwiatowy',
#   'owoc',
#   'Szkocja'],
#  ['monkey',
#   'Shoulder',
#   'whisky',
#   'blended',
#   'Monkey',
#   'Shoulder',
#   'zakorzenić',
#   'historia',
#   'whisky',
#   'słodowy',
#   'zainspirować',
#   'rzemieślnik',
#   'wciąż',
#   'ręcznie',
#   'przetwarzać',
#   'słodować',
#   'jęczmień',
#   'mieszać',
#   'mały',
#   'partia',
#   'dobry',
#   'whisky',
#   'single',
#   'malta',
#   'Speyside',
#   'monkey',
#   'Shoulder',
#   '100',
#   'whisky',
#   'słodowy',
#   'stworzić',
#   'mieszać',
#   'bogactwo',
#   'żywiołowość',
#   'łączyć',
#   'owocowy',
#   'aromata',
#   'łagodny',
#   'nuta',
#   'wanilia',
#   'słodki',
#   'jabłko',
#   'gruszka',
#   'miód',
#   'owoc',
#   'karmel',
#   'miód',
#   'mleczny',
#   'krówka',
#   'pomarańczy',
#   'wanilia',
#   'drewno',
#   'Szkocja'],
#  ['Montebuen',
#   'Rioja',
#   'Alavesa',
#   'wino',
#   'wytrawny',
#   'Hiszpański',
#   'wino',
#   'rubinowy',
#   'kolor',
#   'Cechuje',
#   'aromat',
#   'beczka',
#   'czarny',
#   'porzeczka',
#   'jagóda',
#   'idealny',
#   'mięs',
#   ' ',
#   'czarny',
#   'porzeczka',
#   'jagoda',
#   'Hiszpania'],
#  ['witosha',
#   'premium',
#   'Sweet',
#   'Red',
#   'wino',
#   'słodki',
#   'witosha',
#   'premium',
#   'Sweet',
#   'Red',
#   ' ',
#   'czerwony',
#   'słodki',
#   'bułgarski',
#   'wino',
#   'deserowy',
#   'wino',
#   'podwyższyć',
#   'zawartość',
#   'alkohol',
#   '17',
#   'wyrazisty',
#   'owocowy',
#   'słodki',
#   'smak',
#   ' ',
#   'cytrus',
#   'suszony',
#   'truskawka',
#   'Bułgaria'],
#  ['amundsen',
#   'wódka',
#   'czysty',
#   'Amundsen',
#   'Vodek',
#   'niezwykle',
#   'delikatny',
#   'wódka',
#   'produkować',
#   'Polska',
#   'norweski',
#   'licencja',
#   'swój',
#   'unikalny',
#   'smak',
#   'zawdzięczać',
#   'krystalicznie',
#   'czysty',
#   'woda',
#   'stworzyć',
#   'powolny',
#   'proces',
#   'rektyfikacja',
#   ' ',
#   'najzimniejsza',
#   'rynek',
#   'wódka',
#   'który',
#   'podawać',
#   'należeć',
#   'temperatura',
#   'zero',
#   'st',
#   'Celsjusz',
#   'walor',
#   'odkryć',
#   'tuż',
#   'zamrożenie',
#   'schłodzyć',
#   '0',
#   'stopień',
#   'Celsjusz',
#   'podać',
#   'wydobywać',
#   'walor',
#   'dzikość',
#   'surowość',
#   'mocny',
#   'smak',
#   'charakteryzować',
#   'męski',
#   'świat',
#   'niecodzienny',
#   'wyzwanie',
#   'niesamowity',
#   'przygoda',
#   'mężczyzna',
#   'pierwiastek',
#   'odkrywiec',
#   'wystarczyć',
#   'odnaleźć',
#   'rzucić',
#   'krąg',
#   'przygoda',
#   'podobny',
#   'sprzed',
#   '100',
#   'rok',
#   'pierwszy',
#   'Antarktyd',
#   'stanąć',
#   'ludzki',
#   'stopa',
#   'klucz',
#   'niezwykły',
#   'męski',
#   'świat',
#   'Zdrowej',
#   'rywalizacja',
#   'pokonywać',
#   'własny',
#   'biegun',
#   ' ',
#   'Antarktyda',
#   'świat',
#   'skuty',
#   'lód',
#   'nieskażyć',
#   'pierwotny',
#   'fascynować',
#   'krystaliczny',
#   'czystość',
#   'południowy',
#   'biegun',
#   'lodowy',
#   'krajobraz',
#   'budzić',
#   'respekt',
#   'szacunek',
#   'stać',
#   'inspiracja',
#   'wytworzyć',
#   'zimny',
#   'krystaliczny',
#   'alkohol',
#   'butelka',
#   'dedykować',
#   'wódka',
#   'zostać',
#   'zaprojektować',
#   'oddać',
#   'nieskazitelny',
#   'jakość',
#   'temperatura',
#   'łatwo',
#   'pomylić',
#   'lodowy',
#   'rzeźba',
#   'wyjąć',
#   'wprost',
#   'zamarznięty',
#   'tafla',
#   'doskonale',
#   'współgrać',
#   'zamknąć',
#   ' ',
#   'zawartość',
#   'ekstremalnie',
#   'czysty',
#   'wódka',
#   'stworzć',
#   'uważnie',
#   'wyselekcjonowanych',
#   'składnik',
#   '  ',
#   'Polska'],
#  ['Glenfiddich',
#   '12yo',
#   'whisky',
#   'single',
#   'malta',
#   'starannie',
#   'dojrzewać',
#   'beczka',
#   'sherry',
#   'dobry',
#   'amerykański',
#   'europejski',
#   'dębów',
#   'mało',
#   '12',
#   'rok',
#   'następnie',
#   'dojrzewać',
#   'dębowy',
#   'kadzi',
#   'ślubny',
#   'uzyskać',
#   'słodki',
#   'subtelny',
#   'smak',
#   'dąb',
#   'kremowy',
#   'długi',
#   'gładki',
#   'aksamitny',
#   'wykończenie',
#   '12',
#   'latek',
#   'doskonały',
#   'przykład',
#   'unikalny',
#   'styl',
#   'Speyside',
#   'Glenfiddich',
#   'powszechnie',
#   'uznawać',
#   'najlepszą',
#   'whisky',
#   'dolina',
#   'jeleń',
#   'jabłko',
#   'cytrus',
#   'drewno',
#   'jabłko',
#   'nuta',
#   'kwiatowy',
#   'wanilia',
#   'cytrus',
#   'kremowy',
#   'pieprz',
#   'Szkocja'],
#  ['barmańska',
#   'Pigwa',
#   'wódka',
#   'owocowy',
#   'inspiracja',
#   'powstać',
#   'Barmańskie',
#   'smak',
#   'dojrzały',
#   'soczysty',
#   'owoc',
#   'dzięki',
#   'powstać',
#   'receptura',
#   'udział',
#   'sok',
#   'pigwya',
#   'sprawiać',
#   'Barmańska',
#   'zaskakować',
#   'owocowy',
#   'świeżość',
#   'wyjątkowy',
#   'walor',
#   'wynikać',
#   'idealnie',
#   'dobrać',
#   'proporcja',
#   'alkohol',
#   'pigwowy',
#   'smak',
#   'Najlepiej',
#   'podawać',
#   'schłodzić',
#   'kostka',
#   'lód',
#   'pigwowy',
#   'pigwowy',
#   'Polska'],
#  ['Merlot',
#   'Touriga',
#   'Nacional',
#   'wino',
#   'wytrawny',
#   'wino',
#   'kolor',
#   'rubinowy',
#   'intensywny',
#   'aromat',
#   'agrest',
#   'pomarańcz',
#   'Nadaje',
#   'idealnie',
#   'makaron',
#   'danie',
#   'kurczak',
#   ' ',
#   'agrest',
#   'Pomarańcz',
#   'kawa',
#   'wanilia',
#   'Portugalia'],
#  ['Baileys',
#   'Salted',
#   'Caramel',
#   'likier',
#   'irlandzki',
#   'nalezy',
#   'mieszać',
#   'napoj',
#   'baza',
#   'owoc',
#   'cytrusowy',
#   'kolejny',
#   'urzekający',
#   'profil',
#   'likier',
#   'Baileys',
#   'oferować',
#   'pyszny',
#   'smak',
#   'solony',
#   'karmel',
#   'ukazać',
#   'rynek',
#   'myśl',
#   'zbliżać',
#   'święet',
#   'boży',
#   'Narodzenia',
#   'twórca',
#   'wyobrazić',
#   'siebie',
#   'sam',
#   'siedzieć',
#   'kominek',
#   'kieliszk',
#   'rozgrzewający',
#   'podniebienie',
#   'Baileys',
#   'słuchać',
#   'rodzinny',
#   'opowieść',
#   'oglądających',
#   'ulubiony',
#   'serial',
#   'whiskey',
#   'czekolada',
#   'słony',
#   'karmel',
#   'czekolada',
#   'łagodny',
#   'Irlandia'],
#  ['Astrale',
#   'Rosso',
#   'wino',
#   'wytrawny',
#   'wino',
#   'głęboki',
#   'purpurowy',
#   'barwa',
#   'jasny',
#   'refleks',
#   'bogaty',
#   'aromat',
#   'wyczuwalny',
#   'kompozycja',
#   'dojrzały',
#   'czerwony',
#   'owoc',
#   'delikatny',
#   'przyprawa',
#   ' ',
#   'śliwka',
#   'wanilia',
#   'czarny',
#   'porzeczka',
#   'wiśnia',
#   'Włochy'],
#  ['biały',
#   'bocian',
#   'wódka',
#   'czysty',
#   'biały',
#   'bocian',
#   'polski',
#   'wódka',
#   'premium',
#   'posiadać',
#   'unikalny',
#   'zestaw',
#   'składnik',
#   'dzięki',
#   'oryginalny',
#   'wyrafinowany',
#   'typ',
#   'wódka',
#   'Gluten',
#   'Free',
#   'pochodzić',
#   'wielkopolski',
#   'zboże',
#   'składnik',
#   'dopracować',
#   'dzięki',
#   'posiadać',
#   'wyrazisty',
#   'smak',
#   'delikatny',
#   'subtelny',
#   '  ',
#   'Polska'],
#  ['Glenfiddich',
#   '15yo',
#   'whisky',
#   'single',
#   'malta',
#   'Leżakowana',
#   'europejski',
#   'dębowy',
#   'beczka',
#   'sherry',
#   'nowy',
#   'dębowy',
#   'beczek',
#   'whisky',
#   'zmiękczać',
#   'nasz',
#   'wyjątkowy',
#   'Soler',
#   'Vat',
#   'duży',
#   'dębowy',
#   'kadź',
#   'inspirowanej',
#   'winiarń',
#   'sherry',
#   'Hiszpania',
#   'Portugalia',
#   'opróżniać',
#   'przechowywać',
#   'połowa',
#   'pełny',
#   '1998',
#   'kadź',
#   'Soler',
#   'zwieńczenie',
#   'ciekawski',
#   'umysł',
#   'pionierskiy',
#   'duch',
#   'rodzina',
#   'Grants',
#   'powód',
#   'whisky',
#   'zostać',
#   'pierwszy',
#   '15',
#   'latk',
#   'znaleźć',
#   'pierwszy',
#   'dziesiątka',
#   'dobrze',
#   'sprzedać',
#   'single',
#   'malt',
#   'Sherry',
#   'marcepan',
#   'cynamon',
#   'imbir',
#   'miód',
#   'sherry',
#   'miód',
#   'karmel',
#   'mleczny',
#   'czekolada',
#   'wanilia',
#   'wanilia',
#   'cynamon',
#   'goździk',
#   'drewno',
#   'Szkocja'],
#  ['Bols',
#   'Vodka',
#   'wódka',
#   'czysty',
#   'czysty',
#   'wódka',
#   'produkować',
#   'wykorzystać',
#   'nowatorski',
#   'metoda',
#   'proces',
#   'rektyfikacja',
#   'wykorzystywać',
#   'unikatowy',
#   'hydroselekcja',
#   'pozwalać',
#   'uzyskać',
#   'spirytus',
#   'charakter',
#   'neutralny',
#   'poddawać',
#   'następnie',
#   'wielokrotny',
#   'filtracja',
#   'uszlachetniać',
#   'spirytus',
#   'wytwarzać',
#   'producent',
#   'spełniać',
#   'wysoki',
#   'wymaganie',
#   'technologiczny',
#   'stały',
#   'kontrola',
#   'nadzór',
#   'jakość',
#   'firma',
#   'Bols',
#   'Bols',
#   'holenderski',
#   'marka',
#   'wódka',
#   'istniejący',
#   '1575',
#   'rok',
#   'upamiętniać',
#   'herb',
#   'etykieta',
#   'alkohol',
#   'Polska',
#   'produkować',
#   '1994',
#   'rok',
#   'wódka',
#   'Bols',
#   'zostać',
#   'wyróżniyć',
#   '2010',
#   'rok',
#   'prestiżowy',
#   'tytuł',
#   'Wyjątkowej',
#   'Jury',
#   'International',
#   'Taste',
#   'Quality',
#   'Institute',
#   'konkurs',
#   'Superior',
#   'Taste',
#   'Award',
#   'alkohole',
#   'analizować',
#   'inny',
#   'wzgląd',
#   'pierwszy',
#   'wrażenie',
#   'smak',
#   'zapach',
#   'kategoria',
#   'otrzymać',
#   'wysoki',
#   'nota',
#   'zaowocować',
#   'przyznać',
#   'BOLS',
#   'Premium',
#   'Vodka',
#   'wysoki',
#   'nagroda',
#   'trzy',
#   'gwiazdeka',
#   'uzyskywać',
#   'miano',
#   'Exceptional',
#   'wyjątkowy',
#   'formuła',
#   'test',
#   'zakładać',
#   'degustacja',
#   'produkt',
#   'identyfikacja',
#   'marka',
#   'opakowanie',
#   'wieloosobowy',
#   'międzynarodowy',
#   'komisja',
#   'pozwalać',
#   'potwierdzić',
#   'rzeczywisty',
#   'jakość',
#   'trunek',
#   'wpływ',
#   'marka',
#   'wariant',
#   'wódka',
#   'BOLS',
#   'produkować',
#   'nowocześny',
#   'zakład',
#   'rektyfikacyjny',
#   'świat',
#   'Oborniki',
#   'Wielkopolski',
#   'wódka',
#   'poddawać',
#   '4',
#   'krotnemu',
#   'proces',
#   'destylacja',
#   'filtracja',
#   'węglowy',
#   'miedziowy',
#   'dzięki',
#   'czystość',
#   'przewyższać',
#   '5',
#   'krotnie',
#   'restrykcyjny',
#   'unijny',
#   'norma',
#   'sprawiać',
#   'niezwykle',
#   'łagodny',
#   'smak',
#   'zapach',
#   'pozostawiać',
#   'podniebienie',
#   'wyczuwalny',
#   'esencja',
#   'wódka',
#   'wysoki',
#   'jakość',
#   '  ',
#   'Polska'],
#  ['Chopin',
#   'wódka',
#   'czysty',
#   'Chopin',
#   'Rye',
#   'wódka',
#   'wywodząca',
#   'polski',
#   'Podlasia',
#   'Wytwarzać',
#   'legendarny',
#   'Polmos',
#   'Siedlce',
#   'wysoki',
#   'jakość',
#   'żyty',
#   'proces',
#   'wytwarzać',
#   'wódka',
#   'Chopin',
#   'podobny',
#   'metoda',
#   'stosować',
#   'rok',
#   'wódka',
#   'zawierać',
#   'dodatek',
#   'sekret',
#   'tkwić',
#   'prostota',
#   'produkcja',
#   'odpowiedni',
#   'selekcja',
#   'składnik',
#   'Chopin',
#   'Rye',
#   'charakteryzować',
#   'delikatny',
#   'bogaty',
#   'zrównoważony',
#   'smakie',
#   'odrobina',
#   'pikantny',
#   'finisz',
#   'wyraźny',
#   'aromat',
#   'żytni',
#   'chleb',
#   'lekko',
#   'surowy',
#   'nuta',
#   '  ',
#   'Polska'],
#  ['tullamore',
#   'D',
#   'E',
#   'whisky',
#   'blended',
#   'Tullamore',
#   'D',
#   'E',
#   'oryginalny',
#   'irlandzka',
#   'whiskey',
#   'typ',
#   'triple',
#   'blend',
#   'znać',
#   'cały',
#   'świat',
#   'swój',
#   'delikatny',
#   'łagodny',
#   'głębia',
#   'złożony',
#   'przystępny',
#   'smak',
#   'whiskey',
#   'brać',
#   'trzy',
#   'rodzaj',
#   'ziarno',
#   'potrójny',
#   'destylacja',
#   'połączyć',
#   'trzy',
#   'rodzaj',
#   'irlandzki',
#   'whiskey',
#   'okres',
#   'rok',
#   'dojrzewać',
#   'tradycyjny',
#   'uprzednio',
#   'używać',
#   'beczek',
#   'beczka',
#   'burbonać',
#   'beczka',
#   'sherry',
#   'słodki',
#   'karmel',
#   'czekolada',
#   'owoc',
#   'karmel',
#   'drewno',
#   'nuta',
#   'korzenny',
#   'drewno',
#   'Irlandia'],
#  ['Monte',
#   'dać',
#   'Ravasqueir',
#   'Superior',
#   'Tinto',
#   'wino',
#   'wytrawny',
#   'wino',
#   'głęboki',
#   'purpurowy',
#   'kolor',
#   'silny',
#   'aromat',
#   'beczka',
#   'owoc',
#   'idealny',
#   'mięs',
#   ' ',
#   'aromat',
#   'beczka',
#   'śliwka',
#   'czarny',
#   'porzeczka',
#   'Portugal'],
#  ['Beefeater',
#   'London',
#   'gin',
#   'destylować',
#   'Produkować',
#   'niezmienny',
#   'szlachetny',
#   'wielki',
#   'wprawa',
#   '9',
#   'dobry',
#   'ręcznie',
#   'wybrać',
#   'zioło',
#   'mocny',
#   'wyrazisty',
#   'jałowiec',
#   'cytrus',
#   'Jałowiec',
#   'cytrus',
#   'lukrecja',
#   'średnio',
#   'długi',
#   'jałowiec',
#   'Londyn'],
#  ['Finlandia',
#   'wódka',
#   'czysty',
#   'wódka',
#   'Finlandia',
#   'produkować',
#   'uprawiać',
#   'Finlandia',
#   'sześciorzędowy',
#   'jęczmienie',
#   'czysty',
#   'woda',
#   'źródlany',
#   'lodowiec',
#   'woda',
#   'naturalnie',
#   'filtrować',
#   'morena',
#   'pozostały',
#   'zejść',
#   'lodowiec',
#   'tysiąc',
#   'rok',
#   'wódka',
#   'potrzebować',
#   'żaden',
#   'filtracja',
#   'inny',
#   'sztuczny',
#   'oczyszczać',
#   'przeciwieństwo',
#   'niektóry',
#   'wódeka',
#   'Składniki',
#   'nadawać',
#   'wódka',
#   'wytrawny',
#   'lekki',
#   'gładki',
#   'smak',
#   'delikatny',
#   'aromat',
#   '  ',
#   'Finlandia'],
#  ['Gianduia',
#   'Bottega',
#   'likier',
#   'mleczny',
#   'ekskluzywny',
#   ' ',
#   'likier',
#   'bogaty',
#   'charakter',
#   'stanowić',
#   'idealny',
#   'połączenie',
#   'włoski',
#   'grappy',
#   ' ',
#   'smakiem',
#   'doskonały',
#   'mleczny',
#   'czekolada',
#   'lada',
#   'gratka',
#   'amator',
#   'wytworny',
#   'trunek',
#   '    ',
#   'Włochy'],
#  ['hlibny',
#   'dar',
#   'wódka',
#   'czysty',
#   'Hlibny',
#   'Dar',
#   'nieskazitelny',
#   'ukraiński',
#   'wódka',
#   'wódka',
#   'uznawać',
#   'światowy',
#   'rankinge',
#   'renomowany',
#   'nagroda',
#   'słusznie',
#   'zajmować',
#   'miejsce',
#   'pierwszy',
#   'trójka',
#   'Wykonana',
#   'wyłącznie',
#   'naturalny',
#   'składnik',
#   'wysoki',
#   'jakość',
#   'alkohol',
#   'klasa',
#   'Lux',
#   'ekologicznie',
#   'czysty',
#   'woda',
#   'studnia',
#   'artezyjski',
#   'diamentowy',
#   'przezroczystość',
#   'napój',
#   'zapewniać',
#   'liczny',
#   'etap',
#   'technologia',
#   'czyszczyć',
#   'nowy',
#   'generacja',
#   'wybór',
#   'człowiek',
#   'zmieniać',
#   'świat',
#   '10',
#   'rok',
#   'rząd',
#   'Hlebniy',
#   'dar',
#   'uosabiać',
#   'nienaganny',
#   'jakość',
#   '  ',
#   'Ukraina'],
#  ['Chivas',
#   'Regal',
#   '12yo',
#   'whisky',
#   'blended',
#   'Chivas',
#   '12',
#   'powód',
#   'klasyk',
#   'Skomponować',
#   'najwyborniejszy',
#   'szkocki',
#   'whisky',
#   'słodowy',
#   'zbożowy',
#   '12',
#   'letnia',
#   'mieszanka',
#   'flagowy',
#   'whisky',
#   'marka',
#   'Chivas',
#   'Rega',
#   'zawodzić',
#   'wyrafinowany',
#   'podniebienie',
#   'Harmonijne',
#   'połączenie',
#   'klucz',
#   'sukces',
#   'zarówno',
#   'życie',
#   'szkocki',
#   'podstawę',
#   'nasz',
#   'charakterystyczny',
#   '12',
#   'letniej',
#   'mieszanka',
#   'stanowić',
#   'kultowy',
#   'smak',
#   'region',
#   'Speyside',
#   'Chrupiące',
#   'owoc',
#   'zebrać',
#   'sad',
#   'dziki',
#   'wrzos',
#   'słodki',
#   'miód',
#   'stanowić',
#   'połączenie',
#   'być',
#   'rezultat',
#   'wieloletniy',
#   'doświadczenie',
#   'kunszt',
#   'master',
#   'Blenderów',
#   'miód',
#   'mleczny',
#   'krówka',
#   'jabłko',
#   'drewno',
#   'wanilia',
#   'toffi',
#   'banan',
#   'jabłko',
#   'wanilia',
#   'miód',
#   'nuta',
#   'korzenny',
#   'drewno',
#   'Szkocja'],
#  ['Krupnik',
#   'Cytryna',
#   'likier',
#   'owocowy',
#   'Krupnik',
#   'cytrynowy',
#   'orzeźwiający',
#   'świeży',
#   'aromatyczny',
#   'wódka',
#   'łącząca',
#   'smak',
#   'dojrzały',
#   'soczysty',
#   'cytryna',
#   'wysoki',
#   'klasa',
#   'spirytus',
#   'krystalicznie',
#   'czysty',
#   'woda',
#   'czerpać',
#   'własny',
#   'studnia',
#   'głębinowy',
#   'idealny',
#   'zarówno',
#   'pić',
#   'czysty',
#   'postać',
#   'składnik',
#   'koktajli',
#   'cytrynowy',
#   'cytrynowy',
#   'Polska'],
#  ['Casa',
#   'Hamaca',
#   'rum',
#   'biały',
#   'Casa',
#   'Hamaca',
#   'Ron',
#   'del',
#   'Caribbean',
#   'Blanco',
#   'wybrać',
#   'destylat',
#   'karaibski',
#   'połączyć',
#   'jeden',
#   'harmonijny',
#   'całość',
#   'destylat',
#   'zostać',
#   'starannie',
#   'wyselekcjonować',
#   'rekomendować',
#   'serwować',
#   'wyśmienity',
#   'biały',
#   'rum',
#   'składnik',
#   'koktajli',
#   'mango',
#   'brzoskwiń',
#   'soek',
#   'karambol',
#   'odpowiednio',
#   'dobrać',
#   'ilość',
#   'lód',
#   'kruszony',
#   '  ',
#   'Polska'],
#  ['The',
#   'Singleton',
#   '12yo',
#   'whisky',
#   'single',
#   'malta',
#   '12',
#   'letnia',
#   'szkocki',
#   'whisky',
#   'single',
#   'Malt',
#   'dojrzewać',
#   'duży',
#   'ilość',
#   'beczka',
#   'dąb',
#   'amerykański',
#   'niewielki',
#   'ilość',
#   'beczka',
#   'dąb',
#   'europejski',
#   'zrównoważyć',
#   'płyn',
#   'Rezultatem',
#   'łatwy',
#   'delektować',
#   'single',
#   'malta',
#   'nut',
#   'soczysty',
#   'brązowy',
#   'cukier',
#   'miękki',
#   'gotować',
#   'jabłko',
#   'kremowy',
#   'toffi',
# ...
#   'orzeźwiający',
#   'smak',
#   'skakać',
#   'radość',
#   'chmiel',
#   'słód',
#   'chmiel',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'Oat',
#   'of',
#   'The',
#   'Box',
#   'piwo',
#   'Oatmeal',
#   'Stout',
#   'tradycyjnie',
#   'owsiany',
#   'wyjątkowo',
#   'smaczny',
#   'warzć',
#   'kreatywny',
#   'uniesić',
#   '\n',
#   'Składniki',
#   'woda',
#   'słody',
#   'jęczmienny',
#   'Pale',
#   'karmelowy',
#   '600EBC',
#   'czekoladowy',
#   'ciemny',
#   'barwiący',
#   'obłuszczona',
#   'słody',
#   'pszeniczny',
#   'pszeniczny',
#   'jasny',
#   'płatek',
#   'owsiany',
#   'chmiel',
#   'polski',
#   'drożdże',
#   'górny',
#   'fermentacja',
#   'czekolada',
#   'karmel',
#   'chmiel',
#   'czekolada',
#   'chmiel',
#   'Polska'],
#  ['wrężel',
#   'Obibock',
#   'piwo',
#   'Maibock',
#   'powiedzieć',
#   'kanapa',
#   'uratować',
#   'świat',
#   'piwo',
#   'jasny',
#   'styl',
#   'koźlak',
#   'majowy',
#   'delikatnie',
#   'słodowy',
#   'aromat',
#   'Składniki',
#   'woda',
#   'słody',
#   'jęczmienny',
#   'pilzneński',
#   'Wiedeński',
#   'Monachijski',
#   'ciemny',
#   'karmelowy',
#   '400',
#   'chmiel',
#   'Columbus',
#   'USA',
#   'drożdże',
#   'Fermentis',
#   'S',
#   '189',
#   'karmel',
#   'słód',
#   'karmel',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'BOWMORE',
#   'piwo',
#   'peated',
#   'bis',
#   'barrel',
#   'aged',
#   'Russian',
#   'Imperial',
#   'Stout',
#   'lekko',
#   'palyć',
#   'torfowy',
#   'nuta',
#   'pochodzić',
#   'wędzonego',
#   'słód',
#   'poddać',
#   'proces',
#   'leżakować',
#   'dębowy',
#   'beczka',
#   'whisky',
#   'szkocki',
#   'destylarnia',
#   'Bowmore',
#   'karmel',
#   'czekolada',
#   'chmiel',
#   'czekolada',
#   'chmiel',
#   'Polska'],
#  ['wrężel',
#   'Peated',
#   'RIS',
#   'Buffalo',
#   'Trace',
#   'Barrel',
#   'Aged',
#   'piwo',
#   'Peated',
#   'RIS',
#   'BA',
#   'czarny',
#   'złoto',
#   'browarnictwo',
#   'torfowy',
#   'nut',
#   'wędzoć',
#   'słód',
#   'Leżakować',
#   'beczka',
#   'whisky',
#   'Buffalo',
#   'Trace',
#   '\n',
#   'piwo',
#   'ciemny',
#   'pasteryzować',
#   'niefiltrować',
#   'czekolada',
#   'whisky',
#   'whisky',
#   'Polska'],
#  ['wrężel',
#   'Peated',
#   'RIS',
#   'Heaven',
#   'Hill',
#   'Barrel',
#   'Aged',
#   'piwo',
#   'Peated',
#   'RIS',
#   'BA',
#   'Mocny',
#   'esencjonalny',
#   'rozgrzewające',
#   'lekko',
#   'palyć',
#   'torfowy',
#   'nuta',
#   'pochodzić',
#   'wędzonego',
#   'słód',
#   'poddać',
#   'proces',
#   'leżakować',
#   'dębowy',
#   'beczka',
#   'wspaniały',
#   'whisky',
#   'Heaven',
#   'Hill',
#   '\n',
#   'SKŁADNIKI',
#   'woda',
#   'słody',
#   'jęczmienny',
#   'Château',
#   'Whisky',
#   'Monachijski',
#   'typ',
#   'czekoladowy',
#   'ciemny',
#   'karmelowy',
#   '300',
#   'barwiący',
#   'płatek',
#   'błyskawiczny',
#   'płatek',
#   'owsiany',
#   'herbata',
#   'Lapsang',
#   'wędzony',
#   'korzenia',
#   'bambus',
#   'chmiel',
#   'amerykański',
#   'Columbus',
#   'drożdże',
#   'S',
#   '04',
#   'czekolada',
#   'czekolada',
#   'Polska'],
#  ['wrężel',
#   'Tropical',
#   'Wild',
#   'Bowmore',
#   'BA',
#   'piwo',
#   'Brett',
#   'IPA',
#   'BA',
#   'edycja',
#   'limitować',
#   'piwo',
#   'wydać',
#   'okazja',
#   '5',
#   'urodziny',
#   'browar',
#   'Zostało',
#   'poddać',
#   'dodatkowy',
#   'fermentacja',
#   'drożdż',
#   'Amalagamation',
#   'Brett',
#   'super',
#   'Blend',
#   'THE',
#   'YEAST',
#   'BAY',
#   'leżakować',
#   'beczka',
#   'whisky',
#   'Karmel',
#   'miód',
#   'whisky',
#   'karmel',
#   'whisky',
#   'miód',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'Tropical',
#   'IPA',
#   'piwo',
#   'Imperial',
#   'IPA',
#   'piwo',
#   'uwarzyć',
#   'Browar',
#   'Wrężel',
#   'miejscowość',
#   'Zarzecze',
#   'powiat',
#   'żywiecki',
#   'województwo',
#   'śląski',
#   '\n\n',
#   'tropikalny',
#   'wersja',
#   'Imperialny',
#   'IPA',
#   'maksymalnie',
#   'goryczkowy',
#   'maksymalnie',
#   'owocowy',
#   'maksymalnie',
#   'aromatyczny',
#   'połączyć być',
#   'smak',
#   'tropikalny',
#   'owoc',
#   'bardzo',
#   'aromatyczny',
#   'gatunek',
#   'chmiel',
#   'zza',
#   'wielki',
#   'woda',
#   'piwo',
#   'znajdziesz',
#   'potrzebny',
#   'poczuć',
#   'raj',
#   'zastanawiać',
#   'długo',
#   'Łap',
#   'butelka',
#   'mango',
#   'Pomarańcz',
#   'kokos',
#   'mango',
#   'Pomarańcz',
#   'kokos',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'Sail',
#   'piwo',
#   'American',
#   'IPA',
#   'produkt',
#   'browar',
#   'kontraktowy',
#   'Wrężeleć',
#   'piwo',
#   'warzyć',
#   'Browar',
#   'Zarzecze',
#   'browar',
#   'Wrężel',
#   'powstać',
#   'stosunkowo',
#   'niedawno',
#   'AIPA',
#   'piąty',
#   'piwo',
#   'browar',
#   'pojawić',
#   'rynek',
#   'piwo',
#   'pasteryzować',
#   'niefiltrować',
#   'styl',
#   'American',
#   'India',
#   'Pale',
#   'marzy',
#   'wyprawa',
#   'Stany',
#   'Zjednoczone',
#   'polecać',
#   'AIPA',
#   'uczta',
#   'nos',
#   'jeden',
#   'butelka',
#   'znaleźć',
#   'zarówno',
#   'zapach',
#   'żywiczny',
#   'las',
#   'owoc',
#   'Floryda',
#   'dać',
#   'zwieść',
#   'oszałamiającym',
#   'cytrusowy',
#   'aromat',
#   'osłona',
#   'czaić',
#   'mocny',
#   'uderzyć',
#   'goryczka',
#   'Życzymy',
#   'smaczny',
#   'Karmel',
#   'cytrus',
#   'chmiel',
#   'karmel',
#   'cytrus',
#   'chmiel',
#   'żywica',
#   'Polska'],
#  ['wrężel',
#   'Ricer',
#   'piwo',
#   'Rice',
#   'DDH',
#   'IPA',
#   'Uwarzone',
#   'Browar',
#   'Wrężęl',
#   '\n',
#   'piwo',
#   'styl',
#   'Rice',
#   'DDH',
#   'IPA',
#   '\n',
#   'piwo',
#   'jasny',
#   'pasteryzować',
#   'niefiltrować',
#   '\n',
#   'skład',
#   'woda',
#   'słody',
#   'jęczmienny',
#   'Pilzneński',
#   'Carapils',
#   'płatek',
#   'ryżowy',
#   'chmiel',
#   'amerykański',
#   'drożdże',
#   'chmiel',
#   'owoc',
#   'chmiel',
#   'owoc',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'Rabarbest',
#   'piwo',
#   'Gose',
#   'piwo',
#   'jasny',
#   'wyraźnie',
#   'słony',
#   'smak',
#   'dodatek',
#   'sok',
#   'rabarbar',
#   'agrest',
#   '\n\n',
#   'skład',
#   '\n',
#   'WODA',
#   'SŁODY',
#   'PSZENICZNE',
#   'pszeniczny',
#   'jasny',
#   'SŁODY',
#   'JĘCZMIENNE',
#   'pilzneński',
#   'CHMIEL',
#   'Chinook',
#   'KOLENDRA',
#   'INDYJSKA',
#   'SÓL',
#   'mORSKA',
#   'SOK',
#   'RABARBARU',
#   'SOK',
#   'AGRESTU',
#   'kWAS',
#   'mLEKOWY',
#   'DROŻDŻE',
#   'WB',
#   '06',
#   'rabarbar',
#   'agrest',
#   'słony',
#   'rabarbar',
#   'agrest',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'Pink',
#   'Panther',
#   'piwo',
#   'Weizen',
#   'dusza',
#   'wrężelą',
#   'owocowy',
#   'aromat',
#   'łap',
#   'miks',
#   'pszenica',
#   'różowy',
#   'gujawa',
#   'zaskoczyć',
#   'swój',
#   'wyważyć',
#   'słodycza',
#   'drożdże',
#   'banan',
#   'goździk',
#   'gujawa',
#   'banan',
#   'goździk',
#   'gujawa',
#   'gujawa',
#   'Polska'],
#  ['wrężel',
#   'Pils',
#   'piwo',
#   'Pils',
#   'piwo',
#   'jasny',
#   'klasyczny',
#   'nieskomplikowany',
#   'smak',
#   'zboże',
#   'skórka',
#   'cytryna',
#   'zboże',
#   'goryczka',
#   'Polska'],
#  ['wrężel',
#   'Peatland',
#   'piwo',
#   'Peated',
#   'Russian',
#   'Imperial',
#   'Stout',
#   'Upłynnione',
#   'czarny',
#   'złoto',
#   'torfowy',
#   'aromat',
#   'wędzyć',
#   'słód',
#   'mocny',
#   'esencjonalny',
#   'lekko',
#   'wędzyć',
#   'piwo',
#   'ciemny',
#   'Składniki',
#   'woda',
#   'słody',
#   'jęczmienny',
#   'Château',
#   'Whisky',
#   'Monachijski',
#   'typ',
#   'czekoladowy',
#   'ciemny',
#   'karmelowy',
#   '300',
#   'barwiący',
#   'Płatki',
#   'błyskawiczny',
#   'płatek',
#   'owsiany',
#   'herbata',
#   'Lapsang',
#   'wędzony',
#   'korzenia',
#   'bambus',
#   'chmiel',
#   'amerykański',
#   'Columbus',
#   'drożdże',
#   'S',
#   '04',
#   'opis',
#   'oficjalny',
#   'strona',
#   'browar',
#   'torf',
#   'słód',
#   'torf',
#   'Polska'],
#  ['Pint',
#   'miesiąca',
#   'październik',
#   '2022',
#   'Am',
#   'Lubelski',
#   'Dude',
#   'piwo',
#   'Fresh',
#   'Hop',
#   'Pils',
#   'Polish',
#   'Variety',
#   '2022',
#   'wracać',
#   'korzeń',
#   'odkrywać',
#   'klasyka',
#   'nowo',
#   'raz',
#   'polski',
#   'rarytas',
#   'pils',
#   'uwarzyć',
#   'świeży',
#   'szyszka',
#   'LUBELSKIEGO',
#   'SUPER',
#   'AROMATYCZNEGO',
#   'chmiel',
#   'konkurować',
#   'bardzo',
#   'szlachetny',
#   'odmiana',
#   'wnosić',
#   'piwo',
#   'nuta',
#   'ziołowy',
#   'trawiasty',
#   'korzenny',
#   'nieco',
#   'herbata',
#   'wątek',
#   'kwiatowy',
#   '  ',
#   'Polska'],
#  ['PINTA',
#   'Dym',
#   'piwo',
#   'Rauchbock',
#   '\ufeff\ufeff\ufeff\ufeff\ufeff\ufeff\ufeffPierć',
#   'polski',
#   'Koźlak',
#   'Podwędzać',
#   'pokochać',
#   'rzuć',
#   'jesienny',
#   'eksperyment',
#   'Browar',
#   'PINTA',
#   'ciemny',
#   'gęsty',
#   'przydymiyć',
#   'piwo',
#   'miłośnik',
#   'nowy',
#   'wrażenie',
#   'uwaga',
#   'zawierać',
#   'słody',
#   'wędzć',
#   'dym',
#   'buk',
#   'orzech',
#   'Fermentować',
#   'użyć',
#   'drożdże',
#   'temp',
#   '9',
#   '°',
#   'Celsjusz',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'imperator',
#   'Bałtycki',
#   'piwo',
#   'Baltic',
#   'Porter',
#   'Porter',
#   'Bałtycki',
#   'ciemny',
#   'mocny',
#   'lager',
#   'piwowarski',
#   'skarb',
#   'Polska',
#   'klasyczny',
#   'wersja',
#   'ekstrakt',
#   '20',
#   '°',
#   'Plato',
#   '-warzony',
#   'powodzenie',
#   'polski',
#   'browar',
#   'PINTA',
#   'doceniać',
#   'wartość',
#   'Porter',
#   'Bałtycki',
#   'swój',
#   'robić',
#   'krok',
#   'naprzód',
#   'przedstawiać',
#   'Imperatora',
#   'Bałtycki',
#   'ciemny',
#   'gigant',
#   'słód',
#   'chmiel',
#   'PINTA',
#   'imperator',
#   'Bałtycki',
#   'piwo',
#   'święto',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'imperator',
#   'Bałtycki',
#   'Enigma',
#   'Nelson',
#   'Sauvin',
#   'piwo',
#   'imperialny',
#   'Porter',
#   'Bałtycki',
#   'PINTA',
#   'imperator',
#   'Bałtycki',
#   'Enigma',
#   'Nelson',
#   'Sauvin',
#   'ciemny',
#   'mocny',
#   'imperialny',
#   'Porter',
#   'Bałtycki',
#   'aromat',
#   'smak',
#   'akcent',
#   'pumpernikla',
#   'winogrono',
#   'owoc',
#   'tropikalny',
#   'odmiana',
#   'chmiel',
#   'Australia',
#   'nowy',
#   'Zelandia',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'Pays',
#   'Flamand',
#   'król',
#   'Lata',
#   'Roi',
#   'de',
#   'l',
#   'Eté',
#   'piwo',
#   'Hoppy',
#   'Oatmeal',
#   'Witbier',
#   'drugi',
#   'owoc',
#   'współpraca',
#   'kontraktowy',
#   'browar',
#   'Pint',
#   'francuski',
#   'Brasserie',
#   'du',
#   'Pays',
#   'Flamand',
#   'pierwszy',
#   'piwo',
#   'uwarzoć',
#   'kooperacja',
#   'Księżniczka',
#   'wiosna',
#   'Princesse',
#   'de',
#   'Printemps',
#   'Spring',
#   'Saison',
#   'dostępny',
#   'butelka',
#   'pojemność',
#   '0,75l',
#   'PINTA',
#   'Brasserie',
#   'du',
#   'Pays',
#   'Flamand',
#   'polecać',
#   'gładki',
#   'orzeźwienie',
#   'pić być',
#   'kiedyś',
#   'owsiany',
#   'Witbier',
#   'wspólnie',
#   'Olivier',
#   'Mathiew',
#   'nasz',
#   'kompan',
#   'francuski',
#   'Brasserie',
#   'du',
#   'Pays',
#   'Flamand',
#   'przygotować być',
#   'autorsky',
#   'wersja',
#   'lekki',
#   'cytrusowy',
#   'nachmielonego',
#   'Witbier',
#   'króla',
#   'Lata',
#   'uwarzyć być',
#   'wspólnie',
#   'Browar',
#   'jura',
#   'Zawiercie',
#   'koniec',
#   'kwiecień',
#   'dzień',
#   'warszawski',
#   'festiwal',
#   'piwo',
#   '15',
#   'zasyp',
#   'płatek',
#   'owsiać',
#   'piwo',
#   'gładko',
#   'gasić',
#   'pragnienie',
#   'Chmielenie',
#   'francuski',
#   'Strisselspalter',
#   'amerykański',
#   'Citrą',
#   'pierwszy',
#   'warka',
#   'zostać',
#   'rozlać',
#   'wyłącznie',
#   'beczka',
#   'połowa',
#   'pojechać',
#   'Francja',
#   'połowa',
#   'rozesłać być',
#   'polski',
#   'pubów',
#   'kolejny',
#   'warka',
#   'przygotować',
#   'król',
#   'Lata',
#   'butelka',
#   'pojawić',
#   'lato',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'Hop',
#   'Pokus',
#   'piwo',
#   'Black',
#   'India',
#   'Pale',
#   'dawno',
#   'nazwa',
#   'browar',
#   'Hopus',
#   'Pokus',
#   'nowy',
#   'magiczny',
#   'propozycja',
#   'browar',
#   'Pint',
#   'Hopus',
#   'Pokus',
#   'piwo',
#   'styl',
#   'Black',
#   'India',
#   'Pale',
#   'barwa',
#   'ciemnobrązowy',
#   'stosunkowo',
#   'przejrzysty',
#   'wysycenie',
#   'poziom',
#   'wysoki',
#   'piana',
#   'średni',
#   'beżowy',
#   'delikatny',
#   'pozostawiać',
#   'drobny',
#   'ślad',
#   'szkło',
#   'ważny',
#   'utrzymywać',
#   '0,5',
#   'centymetr',
#   'koniec',
#   'picie',
#   'aromat',
#   'intensywny',
#   'wyczuwalny',
#   'amerykański',
#   'chmiel',
#   'owoc',
#   'cytrusowy',
#   'palyć',
#   'słody',
#   'smak',
#   'dodatkowo',
#   'pojawiać',
#   'intensywny',
#   'goryczka',
#   'faktycznie',
#   'spodziewać',
#   '66',
#   'IBU',
#   'piwo',
#   'wydawać',
#   'skoncentrowany',
#   'przyjemnie',
#   'pijalny',
#   'Zawartość',
#   'alkohol',
#   '6,3',
#   'zwyczajny',
#   'typ',
#   'piwa',
#   'czuć',
#   'konsumpcja',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'Sun',
#   'super',
#   'piwo',
#   'Hazy',
#   'Pale',
#   'piwo',
#   'uwarzć',
#   'Browar',
#   'Pint',
#   'wieprze',
#   'województwo',
#   'śląski',
#   'powiat',
#   'żywiecki',
#   '\n\n',
#   'PINTA',
#   'Sun',
#   'Super',
#   'orzeźwiający',
#   'zmętniyć',
#   'dodatek',
#   'płatek',
#   'owsiany',
#   'pszenny',
#   'chmielowy',
#   'piwo',
#   'styl',
#   'Haza',
#   'Pale',
#   '  ',
#   'Polska'],
#  ['Pint',
#   '`',
#   'la',
#   'Grodziskie',
#   'piwo',
#   'Grodziski',
#   'oryginalny',
#   'polski',
#   'lekki',
#   'piwo',
#   'górny',
#   'fermentacja',
#   'piwo',
#   'jasny',
#   'słomkowy',
#   'mętny',
#   'piana',
#   'drobnoziarnisty',
#   'niewysoki',
#   'znikać',
#   'szybko',
#   'zapach',
#   'drożdżowy',
#   'subtelny',
#   'smak',
#   'dymiony',
#   'słód',
#   'intensywny',
#   'goryczka',
#   'chmiel',
#   'lubelski',
#   'lekko',
#   'kwaskowate',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'Havana',
#   'Stout',
#   'piwo',
#   'Foreign',
#   'extra',
#   'Stout',
#   'Uwarzone',
#   'kontraktowy',
#   'browar',
#   'Pint',
#   'Browar',
#   'Jura',
#   'Zawiercie',
#   'ramy',
#   'akcja',
#   'Pint',
#   'miesiąca',
#   'PINTA',
#   'miesiąca',
#   'specjalny',
#   'akcja',
#   'piwowarski',
#   'miesiąc',
#   'prezentywać',
#   'zupełnie',
#   'nowy',
#   'piwo',
#   'Eksperymentujemy',
#   'receptura',
#   'surowca',
#   'kooperować',
#   'pasjonat',
#   'Polska',
#   'zagranica',
#   'Przygotowujemy',
#   'jednorazowo',
#   '100',
#   'beczka',
#   'piwo',
#   'dostępny',
#   'wyłącznie',
#   'beczka',
#   'puba',
#   'biorących',
#   'udział',
#   'akcja',
#   'wykluczać',
#   'piwo',
#   'wzbudzić',
#   'pozytywny',
#   'emocja',
#   'warzyć',
#   'duży',
#   'skala',
#   'przyszłość',
#   'dostępny',
#   'regularny',
#   'sprzedaż',
#   'beczka',
#   'butelka',
#   'premier',
#   'każdy',
#   'piwo',
#   'planować',
#   'II',
#   'połowa',
#   'miesiąc',
#   'luty',
#   'grudzień',
#   'Nazwę',
#   'styl',
#   'każdy',
#   'nowy',
#   'piwo',
#   'ogłaszać',
#   'dzień',
#   'premiera',
#   'informacja',
#   'szukajć',
#   'między innymi',
#   'kalendarz',
#   'dostępny',
#   'puba',
#   'serwować',
#   'PINTĘ',
#   'miesiąca',
#   '  ',
#   'Polska'],
#  ['Miłosław',
#   'Makłowicz',
#   'ArcyIP',
#   'piwo',
#   'Session',
#   'Hazy',
#   'IPA',
#   'Wybierz',
#   'piwny',
#   'podróż',
#   'Robert',
#   'Makłowicze',
#   '\n',
#   'browar',
#   'Fortuna',
#   'jedyny',
#   'browar',
#   'podejmować',
#   'współpraca',
#   'popularny',
#   'znawca',
#   'kulinarny',
#   'podróżnik',
#   ' ',
#   'orzeźwiający',
#   'piwo',
#   'IPA',
#   'goryczka',
#   'nuta',
#   'cytrus',
#   'zbalansować',
#   'smak',
#   'promocja',
#   'piwo',
#   'Robert',
#   'Makłowicze',
#   'szeroki',
#   'dotarcie',
#   'odbiorca',
#   ' ',
#   'autor',
#   'kanał',
#   'YT',
#   '455',
#   'subskrybent',
#   'propozycja',
#   'foodpairing',
#   'piwny',
#   'edukacja',
#   'piwo',
#   'pijalny',
#   'idealny',
#   'towarzysz',
#   'potrawa',
#   'wyróżniający',
#   'kompozycja',
#   '5',
#   'chmiel',
#   'nowy',
#   'odmiana',
#   'polski',
#   'chmiel',
#   'rodzimy',
#   'plantator',
#   'Polish',
#   'Hops',
#   'receptura',
#   'Browar',
#   'Fortuna',
#   'chmieleniem',
#   'zimno',
#   '100',
#   'naturalny',
#   'składnik',
#   '  ',
#   'Polska'],
#  ['Pint',
#   'Dyniamit',
#   'piwo',
#   'Pumpkin',
#   'szaleństwo',
#   'kolor',
#   'ciemny',
#   'pomarańcz',
#   'sezonowy',
#   'jesienno',
#   'zimowy',
#   'dyniowy',
#   'PINTA',
#   'interpretacja',
#   'amerykański',
#   'specjalność',
#   'styl',
#   'Pumpkin',
#   'PINTA',
#   'Dyniamit',
#   'warzyć',
#   'duży',
#   'dodatek',
#   'pieczyć',
#   'dynia',
#   'intensywnie',
#   'naturalnie',
#   'aromatyzować',
#   'cynamon',
#   'goździka',
#   'imbir',
#   '  ',
#   'Polska'],
#  ['notecki',
#   'bursztynowy',
#   'piwo',
#   'pała',
#   'lager',
#   'Ciemny',
#   'pasteryzować',
#   'piwo',
#   'rżnąć',
#   'charakteryzuć',
#   'słodycza',
#   'goryczka',
#   'słodycz',
#   'goryczka',
#   'słodycz',
#   'goryczka',
#   'słodycz',
#   'goryczka',
#   'Polska'],
#  ['Celtic',
#   'Surprise',
#   'piwo',
#   'dry',
#   'stout',
#   'pora',
#   'zawrężlić',
#   'przygodny',
#   'smak',
#   'przenieść',
#   'płynąć',
#   'piwo',
#   'kraina',
#   'zielony',
#   'pagórek',
#   'wystarczyć',
#   'spróbować',
#   'dry',
#   'Stout',
#   ' ',
#   'karmel',
#   'orzech',
#   'czekolada',
#   'wytrawny',
#   'czekolada',
#   'karmel',
#   'orzech',
#   'Polska'],
#  ['Celtic',
#   'Surprise',
#   'Two',
#   'piwo',
#   'irish',
#   'red',
#   'kierunek',
#   'podróż',
#   'zielony',
#   'wyspa',
#   'Wrężluj',
#   'smakiem',
#   'czerwony',
#   'piwo',
#   'przyjemny',
#   'lekki',
#   'aromat',
#   'słodowy',
#   'odkryj',
#   'tajemnica',
#   'Irlandia',
#   'słód',
#   'słód',
#   'słód',
#   'Polska'],
#  ['Cherry',
#   '1',
#   'piwo',
#   'cherry',
#   'barley',
#   'wine',
#   'Rozsmakuj',
#   'mocny',
#   'tradycyjnie',
#   'uwarzoć',
#   'piwo',
#   'dodatek',
#   'sok',
#   'wiśnia',
#   'mocny',
#   'esencjonalny',
#   'słodowy',
#   'piwo',
#   'jasny',
#   'dodatek',
#   'sok',
#   'wiśnia',
#   'wiśnia',
#   'słód',
#   'wiśnia',
#   'słód',
#   'wiśnia',
#   'słód',
#   'Polska']]

# %%
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]
lda_model = models.ldamodel.LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics)
index = similarities.MatrixSimilarity(corpus)

# %%
# save everything above?

# %%
coo = coo_matrix(index)
csr = coo.tocsr()

# %%
xs, ys = coo.nonzero()

operations = []
for x, y in zip(xs, ys):

    if x == y:
        continue

    sim = float(csr[x, y]) #similarity
    if sim < 0.1:
        continue
    x_id = str(items[x]['_id']) #source
    y_id = str(items[y]['_id']) #target
    operations.append(InsertOne({'source': x_id, 'target': y_id, 'sim': sim}))
    # save to db

# %%
db['lda_sim'].bulk_write(operations)

# %%
# zapisane w bazie, zaimplementować by serwować:
# https://github.dev/practical-recommender-systems/moviegeek/blob/ca994bad8bad4a662e8dd65a658e0e4d16d427e8/recs/content_based_recommender.py

# %%
lda_model.print_topics()
# Out:
# [(85,
#   '0.031*"chmiel" + 0.028*"wiśniowy" + 0.021*"Polska" + 0.021*"Lubelska" + 0.020*"goryczka" + 0.019*"piwo" + 0.019*"Zwierzyniecki" + 0.019*"likier" + 0.019*"zapach" + 0.018*"wiśniówka"'),
#  (103,
#   '0.028*"piwo" + 0.025*"grejpfrut" + 0.024*"cytrus" + 0.024*"cytrusowy" + 0.024*"chmiel" + 0.024*"Witbier" + 0.020*"Polska" + 0.020*"orzeźwiający" + 0.019*"dodatek" + 0.015*"absolwent"'),
#  (230,
#   '0.037*"Polska" + 0.036*"piwo" + 0.025*"smak" + 0.022*"piwny" + 0.021*"gruszka" + 0.021*"napój" + 0.017*"  " + 0.016*"czysty" + 0.014*"chmielowy" + 0.012*"słodowy"'),
#  (232,
#   '0.026*"piwo" + 0.024*"Polska" + 0.020*"smak" + 0.017*"słód" + 0.016*"dubeltowy" + 0.016*"chmiel" + 0.013*"słodki" + 0.013*"jasny" + 0.012*"goryczka" + 0.011*"pełny"'),
#  (46,
#   '0.046*"piwo" + 0.033*"Brain" + 0.033*"Moczybroda" + 0.023*"owocowy" + 0.022*"Polska" + 0.020*"goryczka" + 0.017*"typ" + 0.017*"ipa" + 0.017*"chmielć" + 0.017*"India"'),
#  (199,
#   '0.036*"wanilia" + 0.022*"rum" + 0.022*"czekolada" + 0.018*"dębina" + 0.018*"przyprawa" + 0.018*"Barbados" + 0.015*"beczka" + 0.014*"dług" + 0.014*"Black" + 0.014*"cynamon"'),
#  (88,
#   '0.029*"czarny" + 0.024*"wino" + 0.024*"porzeczka" + 0.023*"wanilia" + 0.017*"whisky" + 0.016*" " + 0.016*"owoc" + 0.015*"piwo" + 0.013*"browar" + 0.012*"smak"'),
#  (13,
#   '0.041*"wanilia" + 0.040*"granat" + 0.032*"smak" + 0.024*"pomarańcz" + 0.016*"jajeczny" + 0.016*"pomarańcza" + 0.016*"warka" + 0.016*"likier" + 0.016*"kokos" + 0.016*"naturalny"'),
#  (75,
#   '0.051*"piwo" + 0.043*"Polska" + 0.029*"jałowiec" + 0.029*"słodki" + 0.029*"pomarańcz" + 0.022*"smak" + 0.022*"lager" + 0.014*"orzech" + 0.014*"dry" + 0.014*"goryczka"'),
#  (83,
#   '0.016*"piwo" + 0.015*"wino" + 0.011*" " + 0.011*"nowy" + 0.011*"Essence" + 0.011*"Polska" + 0.010*"Tea" + 0.010*"przyprawa" + 0.009*"herbaciany" + 0.009*"goryczka"'),
#  (24,
#   '0.032*"SŁODY" + 0.022*"piwo" + 0.021*"®" + 0.021*"melon" + 0.021*"chmiel" + 0.021*"wino" + 0.014*"idealny" + 0.014*" " + 0.014*"Polska" + 0.013*"Ciechan"'),
#  (220,
#   '0.052*"piwo" + 0.017*"Polska" + 0.014*"pełny" + 0.013*"smak" + 0.013*"goryczka" + 0.013*"jasny" + 0.012*"  " + 0.011*"chmiel" + 0.010*"lekki" + 0.009*"charakter"'),
#  (174,
#   '0.044*"wódka" + 0.043*"Stock" + 0.043*"żurawina" + 0.023*"lód" + 0.022*"Polska" + 0.022*"koneser" + 0.022*"Cranberry" + 0.022*"specjalnie" + 0.022*"cranberry" + 0.022*"koktajl"'),
#  (167,
#   '0.036*"piwo" + 0.024*"owoc" + 0.018*"smak" + 0.015*"Polska" + 0.014*"czekolada" + 0.014*"goryczka" + 0.012*"średnio" + 0.012*"kawa" + 0.012*"delikatny" + 0.011*"słodki"'),
#  (139,
#   '0.037*"piwo" + 0.026*"wino" + 0.023*"chmiel" + 0.018*"\n" + 0.017*"smak" + 0.016*"owoc" + 0.016*"Polska" + 0.013*"DDH" + 0.013*"IPA" + 0.011*" "'),
#  (192,
#   '0.034*"cachacy" + 0.025*"guarana" + 0.025*"tequila" + 0.022*"piwo" + 0.019*"whisky" + 0.014*"Polska" + 0.014*"aromat" + 0.012*"Peated" + 0.012*"RIS" + 0.011*"smak"'),
#  (2,
#   '0.043*"piwo" + 0.020*"słód" + 0.018*"cytrus" + 0.015*"jałowiec" + 0.013*"słodowy" + 0.013*"aromat" + 0.012*"Polska" + 0.011*"dobry" + 0.009*"ręcznie" + 0.009*"smak"'),
#  (78,
#   '0.024*"piwo" + 0.022*"wódka" + 0.022*"Polska" + 0.018*"goryczka" + 0.015*"jasny" + 0.014*"smak" + 0.011*"Porter" + 0.011*"pszeniczny" + 0.010*"nemiroff" + 0.010*"Original"'),
#  (90,
#   '0.018*"wanilia" + 0.018*"każdy" + 0.018*"kokos" + 0.018*"likier" + 0.018*"Coconut" + 0.018*"doskonały" + 0.018*"kokosowy" + 0.018*"Bali" + 0.016*"Turkey" + 0.015*"delikatny"'),
#  (57,
#   '0.045*"kremowy" + 0.045*"delikatny" + 0.023*"Świeże" + 0.023*"kwasowość" + 0.023*"pigwa" + 0.023*"wyrazisty" + 0.023*"lekki" + 0.023*"Australia" + 0.023*"aromat" + 0.023*"Chardonnay"')]
